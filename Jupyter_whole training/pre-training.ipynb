# %%
import numpy as np
import time
from pyDOE import lhs
import matplotlib
# matplotlib.use('Agg')
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import shutil
import pickle
import math
import scipy.io

import tensorflow as tf
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'  # CPU:-1; GPU0: 1; GPU1: 0;
np.random.seed(1111)
tf.compat.v1.set_random_seed(1111)
# Out:
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# 2022-10-21 14:56:03.474325: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.

# %%
misfit = []
misfit1 = []
class DeepHPM:
    # Initialize the class
    def __init__(self, Collo, snap1, vp, uv_layers, lb, ub, ExistModel=0, modelDir=''):

        # Count for callback function
        self.count = 0
        self.vp = vp
        self.loss_rec = []
        self.train_loss = []
        

        # Bounds
        self.lb = lb
        self.ub = ub
    
        #self.rho = 2.6
        #self.vp = 1

        # Collocation point
        self.x_c = Collo[:, 0:1]
        self.y_c = Collo[:, 1:2]
        self.t_c = Collo[:, 2:3]

        # Source wave
        self.x_snap1 = snap1[:, 0:1]
        self.y_snap1 = snap1[:, 1:2]
        self.t_snap1 = snap1[:, 2:3]
        self.u_snap1 = snap1[:, 3:4]
        
     
        # Define layers
        self.uv_layers = uv_layers

        # Initialize NNs
        if ExistModel== 0 :
            self.uv_weights, self.uv_biases = self.initialize_NN(self.uv_layers)
        else:
            self.uv_weights, self.uv_biases = self.load_NN(modelDir, self.uv_layers)
        # tf placeholders
        self.learning_rate = tf.placeholder(tf.float32, shape=[])
        self.x_tf = tf.placeholder(tf.float32, shape=[None, self.x_c.shape[1]])    # Point for postprocessing
        self.y_tf = tf.placeholder(tf.float32, shape=[None, self.y_c.shape[1]])
        self.t_tf = tf.placeholder(tf.float32, shape=[None, self.t_c.shape[1]])

        self.x_c_tf = tf.placeholder(tf.float32, shape=[None, self.x_c.shape[1]])
        self.y_c_tf = tf.placeholder(tf.float32, shape=[None, self.y_c.shape[1]])
        self.t_c_tf = tf.placeholder(tf.float32, shape=[None, self.t_c.shape[1]])

        self.x_snap1_tf = tf.placeholder(tf.float32, shape=[None, self.x_snap1.shape[1]])
        self.y_snap1_tf = tf.placeholder(tf.float32, shape=[None, self.y_snap1.shape[1]])
        self.t_snap1_tf = tf.placeholder(tf.float32, shape=[None, self.t_snap1.shape[1]])
        self.u_snap1_tf = tf.placeholder(tf.float32, shape=[None, self.u_snap1.shape[1]])

        self.x_snap2_tf = tf.placeholder(tf.float32, shape=[None, self.x_snap2.shape[1]])
        self.y_snap2_tf = tf.placeholder(tf.float32, shape=[None, self.y_snap2.shape[1]])
        self.t_snap2_tf = tf.placeholder(tf.float32, shape=[None, self.t_snap2.shape[1]])
        self.u_snap2_tf = tf.placeholder(tf.float32, shape=[None, self.u_snap2.shape[1]])
        
        self.x_snap3_tf = tf.placeholder(tf.float32, shape=[None, self.x_snap3.shape[1]])
        self.y_snap3_tf = tf.placeholder(tf.float32, shape=[None, self.y_snap3.shape[1]])
        self.t_snap3_tf = tf.placeholder(tf.float32, shape=[None, self.t_snap3.shape[1]])
        self.u_snap3_tf = tf.placeholder(tf.float32, shape=[None, self.u_snap3.shape[1]])

        # tf graphs
        self.u_pred = self.net_uv(self.x_tf, self.y_tf, self.t_tf)
        self.u_snap2_pred  = self.net_uv(self.x_snap2_tf, self.y_snap2_tf, self.t_snap2_tf)
        self.u_snap1_pred  = self.net_uv(self.x_snap1_tf, self.y_snap1_tf, self.t_snap1_tf)
        self.u_snap3_pred  = self.net_uv(self.x_snap3_tf, self.y_snap3_tf, self.t_snap3_tf)
    
        self.loss_snap = tf.reduce_mean(tf.square(self.u_snap1_pred - self.u_snap1_tf)) \
                         + tf.reduce_mean(tf.square(self.u_snap2_pred - self.u_snap2_tf))\
                         + tf.reduce_mean(tf.square(self.u_snap3_pred - self.u_snap3_tf)) 

        self.loss = self.loss_snap

        # Optimizer for solution
        self.optimizer = tf.contrib.opt.ScipyOptimizerInterface(self.loss,
                                                                var_list=self.uv_weights + self.uv_biases,
                                                                method='L-BFGS-B',
                                                                options={'maxiter': 20000,
                                                                         'maxfun': 20000,
                                                                         'maxcor': 50,
                                                                         'maxls': 50,
                                                                         'ftol': 1 * np.finfo(float).eps})

        self.optimizer_Adam = tf.train.AdamOptimizer(learning_rate=self.learning_rate)
        self.train_op_Adam = self.optimizer_Adam.minimize(self.loss,
                                                          var_list=self.uv_weights + self.uv_biases)

        # tf session
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        init = tf.global_variables_initializer()
        self.sess.run(init)

    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)


    def save_NN(self, fileDir):
        uv_weights = self.sess.run(self.uv_weights)
        uv_biases = self.sess.run(self.uv_biases)
        with open(fileDir, 'wb') as f:
            # pickle.dump([np.array(uv_weights), np.array(uv_biases)], f)
            pickle.dump([uv_weights, uv_biases], f)
            print("Save NN parameters successfully...")

    def load_NN(self, fileDir, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        with open(fileDir, 'rb') as f:
            uv_weights, uv_biases = pickle.load(f)
            # print(len(uv_weights))
            # print(np.shape(uv_weights))
            # print(num_layers)

            # Stored model must has the same # of layers
            assert num_layers == (len(uv_weights)+1)

            for num in range(0, num_layers - 1):
                W = tf.Variable(uv_weights[num])
                b = tf.Variable(uv_biases[num])
                weights.append(W)
                biases.append(b)
                print("Load NN parameters successfully...")
        return weights, biases

    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1
        # H = X
        H = 2.0 * (X - self.lb) / (self.ub - self.lb) - 1.0
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.sin(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

    def net_uv(self, x, y, t):
        # This NN return sigma_phi
        u = self.neural_net(tf.concat([x, y, t], 1), self.uv_weights, self.uv_biases)
        u = u[:, 0:1]
        return u 

    def net_f_sig(self, x, y, t):
        vp =self.vp
                 
        u = self.net_uv(x, y, t)
        ut = tf.gradients(u, t)[0]
        u_tt = tf.gradients(ut, t)[0]

        u_x = tf.gradients(u, x)[0]
        u_y = tf.gradients(u, y)[0]
        u_xx = tf.gradients(u_x, x)[0]
        u_yy = tf.gradients(u_y, y)[0]

        f_u = u_tt - vp*vp*(u_xx + u_yy)
        return f_u

    def callback(self, loss):
        self.count = self.count + 1
        print('{} th iterations, Loss: {}'.format(self.count, loss))
        self.train_loss.append(loss)

    def train(self, iter, learning_rate, batch_num):


        #loss_f = []
        loss_snap = []
        loss = []

        # The collocation point is splited into partitions of batch_num，1 epoch for training
        for i in range(batch_num):
            col_num = self.x_c.shape[0]
            idx_start = int(i * col_num / batch_num)
            idx_end = int((i + 1) * col_num / batch_num)

            tf_dict = {self.x_c_tf: self.x_c[idx_start:idx_end,:], self.y_c_tf: self.y_c[idx_start:idx_end,:], self.t_c_tf: self.t_c[idx_start:idx_end,:],
                       self.x_snap1_tf: self.x_snap1, self.y_snap1_tf: self.y_snap1, self.t_snap1_tf: self.t_snap1, self.u_snap1_tf: self.u_snap1,
                       self.x_snap2_tf: self.x_snap2, self.y_snap2_tf: self.y_snap2, self.t_snap2_tf: self.t_snap2, self.u_snap2_tf: self.u_snap2, 
                       self.x_snap3_tf: self.x_snap3, self.y_snap3_tf: self.y_snap3, self.t_snap3_tf: self.t_snap3, self.u_snap3_tf: self.u_snap3,self.learning_rate: learning_rate}

            for it in range(iter):

                self.sess.run(self.train_op_Adam, tf_dict)

                # Print
                if it % 10 == 0:
                    loss_value = self.sess.run(self.loss, tf_dict)
                    #loss_f_value = self.sess.run(self.loss_f, tf_dict)
                    loss_snap_value = self.sess.run(self.loss_snap, tf_dict)
                    print('It: %d, Loss: %.3e, %.3e' %
                          (it, loss_value, loss_snap_value))

                #loss_f.append(self.sess.run(self.loss_f, tf_dict))
                loss_snap.append(self.sess.run(self.loss_snap, tf_dict))
                self.loss_rec.append(self.sess.run(self.loss, tf_dict))

        return self.loss, loss_snap

    def train_bfgs(self, batch_num):

        for i in range(batch_num):
            col_num = self.x_c.shape[0]
            idx_start = int(i*col_num/batch_num)
            idx_end = int((i+1)*col_num/batch_num)
            tf_dict = {self.x_c_tf: self.x_c[idx_start:idx_end,:], self.y_c_tf: self.y_c[idx_start:idx_end,:], self.t_c_tf: self.t_c[idx_start:idx_end,:],
                       #self.x_IC_tf: self.x_IC, self.y_IC_tf: self.y_IC, self.t_IC_tf: self.t_IC,
                       self.x_snap1_tf: self.x_snap1, self.y_snap1_tf: self.y_snap1, self.t_snap1_tf: self.t_snap1, self.u_snap1_tf: self.u_snap1,
                       self.x_snap2_tf: self.x_snap2, self.y_snap2_tf: self.y_snap2, self.t_snap2_tf: self.t_snap2, self.u_snap2_tf: self.u_snap2,
                       self.x_snap3_tf: self.x_snap3, self.y_snap3_tf: self.y_snap3, self.t_snap3_tf: self.t_snap3, self.u_snap3_tf: self.u_snap3}

            self.optimizer.minimize(self.sess,
                                    feed_dict=tf_dict,
                                    fetches=[self.loss],
                                    loss_callback=self.callback)

    def predict(self, x_star, y_star, t_star):
        u_star = self.sess.run(self.u_pred, {self.x_tf: x_star, self.y_tf: y_star, self.t_tf: t_star})
        return u_star

    def probe(self, x_star, y_star, t_star):
        u_star = self.sess.run(self.u_pred, {self.x_tf: x_star, self.y_tf: y_star, self.t_tf: t_star})      
        return u_star
    
    def getloss(self):  # To be updated

        tf_dict = {self.x_c_tf: self.x_c, self.y_c_tf: self.y_c, self.t_c_tf: self.t_c,
                   self.x_snap1_tf: self.x_snap1, self.y_snap1_tf: self.y_snap1, self.t_snap1_tf: self.t_snap1, self.u_snap1_tf: self.u_snap1,
                   self.x_snap2_tf: self.x_snap2, self.y_snap2_tf: self.y_snap2, self.t_snap2_tf: self.t_snap2, self.u_snap2_tf: self.u_snap2,
                   self.x_snap3_tf: self.x_snap3, self.y_snap3_tf: self.y_snap3, self.t_snap3_tf: self.t_snap3, self.u_snap3_tf: self.u_snap3}

        #loss_f = self.sess.run(self.loss_f, tf_dict)
        loss_snap = self.sess.run(self.loss_snap, tf_dict)
        loss = self.sess.run(self.loss, tf_dict)
       
        return loss, loss_snap

# %%
if __name__ == "__main__":


    MAX_T = 1.1
    # Domain bounds
    lb = np.array([0.0, 0.0, 0.2])
    ub = np.array([1, 1, MAX_T])
    lb_sam = np.array([0.0, 0.5, 0.5]) #extra sampling points
    ub_sam = np.array([2, 1, MAX_T])

    # Network configuration
    uv_layers = [3] + 5*[64] + 3*[32]  + [1]

    # Num of collocation point in x, y, t
    N_f = 80000
    
    data_snap1 = scipy.io.loadmat('./ceng_zs0/u_t2.mat')
    data_snap2 = scipy.io.loadmat('./ceng_zs0/u_t4.mat')
    data_snap3 = scipy.io.loadmat('./ceng_zs0/u_t7.mat')
  
    u_snap1 = data_snap1['u_t0'].flatten()[:, None] 
    u_snap2 = data_snap2['u_t0'].flatten()[:, None]
    x_snap1 =  data_snap1['xx'].flatten()[:, None]
    y_snap1 =  data_snap1['zz'].flatten()[:, None]
    x_snap2 =  data_snap2['xx'].flatten()[:, None]
    y_snap2 =  data_snap2['zz'].flatten()[:, None]
    
    u_snap3 = data_snap3['u_t0'].flatten()[:, None] 
    x_snap3 =  data_snap3['xx'].flatten()[:, None]
    y_snap3 =  data_snap3['zz'].flatten()[:, None]
   
    t_snap1 = np.zeros((x_snap1.size, 1))
    t_snap1.fill(0.2)
    t_snap2 = np.zeros((x_snap2.size, 1))
    t_snap2.fill(0.3)
    t_snap3 = np.zeros((x_snap3.size, 1))
    t_snap3.fill(0.7)
    
    snap1 = np.concatenate((x_snap1, y_snap1, t_snap1, u_snap1), 1)
    snap2 = np.concatenate((x_snap2, y_snap2, t_snap2, u_snap2), 1)
    snap3 = np.concatenate((x_snap3, y_snap3, t_snap3, u_snap3), 1)
  
    N = x_snap1.shape[0]
    N_train = round(N/4*4)   
 # Training Data    
    idx = np.random.choice(N, N_train, replace=False)

    snap1_train = snap1[idx,:]
    snap2_train = snap2[idx,:]
    snap3_train = snap3[idx,:]

    # Collocation point
    XYT = lb + (ub - lb) * lhs(3, N_f)
    XYT_c_sam = lb_sam + (ub_sam - lb_sam) * lhs(3, 30000)
    XYT_c = np.concatenate((XYT, XYT_c_sam), 0)
    vp = XYT_c[:,0:1]*0

    A = XYT_c[:,0:1]
    B = XYT_c[:,1:2]    
        
        
    for i in range(len(vp)):
        if B[i]<1:
            vp[i]=1.5
        else:
            vp[i]=1.9

    with tf.device('/device:GPU:0'):

        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        session = tf.Session(config=config)

        model = DeepHPM(XYT_c, snap1_train, snap2_train, snap3_train,  vp, uv_layers, lb, ub)

        loss_snap, loss = model.train(iter=100000, learning_rate=5e-4, batch_num=1)
        model.train_bfgs(batch_num=1)

        model.save_NN('uv_NN_cengpre.pickle')

        model.getloss()

        
        loss_adam_history = model.loss_rec
        scipy.io.savemat('loss_adam_history.mat',{'loss_adam_history':loss_adam_history})
        
        loss_lbfgs_history = model.train_loss
        scipy.io.savemat('loss_lbfgs_history.mat',{'loss_lbfgs_history':loss_lbfgs_history})
        
        train_losshistory = np.concatenate((model.loss_rec,model.train_loss),0)
        scipy.io.savemat('loss_adam+lbfgs.mat',{'train_losshistory':train_losshistory})

        # Output result at each time step
        x_star = np.linspace(0.0, 2, 101)
        y_star = np.linspace(0.0, 2, 101)
        x_star, y_star = np.meshgrid(x_star, y_star)
        x_star = x_star.flatten()[:, None]
        y_star = y_star.flatten()[:, None]
      
        shutil.rmtree('./output', ignore_errors=True)
        os.makedirs('./output')
        t_star_9 = np.zeros((x_star.size, 1))
        t_star_9.fill(0.9)
        u_pred_9 = model.predict(x_star, y_star, t_star_9)
        
        t_star_10 = np.zeros((x_star.size, 1))
        t_star_10.fill(1)
        u_pred_10 = model.predict(x_star, y_star, t_star_10)
        
        t_star_11 = np.zeros((x_star.size, 1))
        t_star_11.fill(1.1)
        u_pred_11 = model.predict(x_star, y_star, t_star_11)
        
    
    
    scipy.io.savemat('u_pred_9.mat',{'u_pred_9':u_pred_9})
    scipy.io.savemat('u_pred_10.mat',{'u_pred_10':u_pred_10})
    
    scipy.io.savemat('u_pred_11.mat',{'u_pred_11':u_pred_11})
   
    fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(21, 14))
    fig.subplots_adjust(hspace=0.15, wspace=0.1)
    
    uu1=ax[0,0].scatter(x_star, y_star, c=u_pred_9,cmap = ('seismic'),vmin=-1.5, vmax=1.5)
    ax[0, 0].set_xticks([])
    ax[0, 0].set_yticks([])
    ax[0, 0].set_title('TD-PINN t=0.9s', fontsize=22)
    cbar = fig.colorbar(uu1, orientation='vertical', ax=ax[0, 0], fraction=0.046, pad=0.04)
    cbar.ax.tick_params(labelsize=12)

    
    uu4=ax[0,1].scatter(x_star, y_star, c=u_pred_10,cmap = ('seismic'),vmin=-1.5, vmax=1.5)
    ax[0, 1].set_xticks([])
    ax[0, 1].set_yticks([])
    ax[0, 1].set_title('TD-PINN t=1.0s', fontsize=22)
    cbar = fig.colorbar(uu4, orientation='vertical', ax=ax[0, 1], fraction=0.046, pad=0.04)
    cbar.ax.tick_params(labelsize=12)
    
 
    uu7=ax[0,2].scatter(x_star, y_star, c=u_pred_11,cmap = ('seismic'),vmin=-1.5, vmax=1.5)
    ax[0, 2].set_xticks([])
    ax[0, 2].set_yticks([])
    ax[0, 2].set_title('TD-PINN t=1.1s', fontsize=22)
    cbar = fig.colorbar(uu7, orientation='vertical', ax=ax[0, 2], fraction=0.046, pad=0.04)
    cbar.ax.tick_params(labelsize=12)

    
    plt.show()
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_64434/2234208611.py:75: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# WARNING:tensorflow:From /tmp/ipykernel_64434/2234208611.py:75: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# WARNING:tensorflow:From /tmp/ipykernel_64434/2234208611.py:77: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# WARNING:tensorflow:From /tmp/ipykernel_64434/2234208611.py:77: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2022-10-21 14:56:05.650932: I tensorflow/core/platform/cpu_feature_guard.cc:145] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX
# 2022-10-21 14:56:05.667851: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2600000000 Hz
# 2022-10-21 14:56:05.673865: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5653552fb9b0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-10-21 14:56:05.673900: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-10-21 14:56:05.675285: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-10-21 14:56:05.684191: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1666] Found device 0 with properties:
# name: NVIDIA GeForce RTX 3090 major: 8 minor: 6 memoryClockRate(GHz): 1.695
# pciBusID: 0000:52:00.0
# 2022-10-21 14:56:05.684245: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-21 14:56:05.690658: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-10-21 14:56:05.693736: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-21 14:56:05.694149: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-21 14:56:05.694950: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2022-10-21 14:56:05.696313: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-10-21 14:56:05.696486: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-10-21 14:56:05.697554: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1794] Adding visible gpu devices: 0
# 2022-10-21 14:56:05.697593: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:From /tmp/ipykernel_64434/1005994725.py:133: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
# 2022-10-21 14:56:06.221538: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1206] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-21 14:56:06.221568: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212]      0
# 2022-10-21 14:56:06.221573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1225] 0:   N
# 2022-10-21 14:56:06.222876: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1351] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13163 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:52:00.0, compute capability: 8.6)
# 2022-10-21 14:56:06.225223: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x565367ecb530 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-10-21 14:56:06.225240: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# WARNING:tensorflow:From /tmp/ipykernel_64434/1005994725.py:133: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
# WARNING:tensorflow:From /tmp/ipykernel_64434/1005994725.py:52: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:From /tmp/ipykernel_64434/1005994725.py:52: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# WARNING:tensorflow:From /tmp/ipykernel_64434/1005994725.py:108: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From /tmp/ipykernel_64434/1005994725.py:108: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:52:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
#
# WARNING:tensorflow:From /tmp/ipykernel_64434/1005994725.py:115: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# 2022-10-21 14:56:07.494800: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1666] Found device 0 with properties:
# name: NVIDIA GeForce RTX 3090 major: 8 minor: 6 memoryClockRate(GHz): 1.695
# pciBusID: 0000:52:00.0
# 2022-10-21 14:56:07.494856: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-21 14:56:07.494870: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-10-21 14:56:07.494880: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-21 14:56:07.494888: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-21 14:56:07.494897: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2022-10-21 14:56:07.494905: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-10-21 14:56:07.494914: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-10-21 14:56:07.495537: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1794] Adding visible gpu devices: 0
# 2022-10-21 14:56:07.495568: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1206] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-21 14:56:07.495572: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212]      0
# 2022-10-21 14:56:07.495576: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1225] 0:   N
# 2022-10-21 14:56:07.496222: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1351] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13163 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:52:00.0, compute capability: 8.6)
# WARNING:tensorflow:From /tmp/ipykernel_64434/1005994725.py:115: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2022-10-21 14:56:07.525563: I tensorflow/core/common_runtime/placer.cc:54] truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525588: I tensorflow/core/common_runtime/placer.cc:54] truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525592: I tensorflow/core/common_runtime/placer.cc:54] truncated_normal: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525597: I tensorflow/core/common_runtime/placer.cc:54] Variable: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525601: I tensorflow/core/common_runtime/placer.cc:54] Variable/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525604: I tensorflow/core/common_runtime/placer.cc:54] Variable/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525608: I tensorflow/core/common_runtime/placer.cc:54] Variable_1: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525611: I tensorflow/core/common_runtime/placer.cc:54] Variable_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525614: I tensorflow/core/common_runtime/placer.cc:54] Variable_1/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525618: I tensorflow/core/common_runtime/placer.cc:54] truncated_normal_1/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525622: I tensorflow/core/common_runtime/placer.cc:54] truncated_normal_1/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525625: I tensorflow/core/common_runtime/placer.cc:54] truncated_normal_1: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525629: I tensorflow/core/common_runtime/placer.cc:54] Variable_2: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525632: I tensorflow/core/common_runtime/placer.cc:54] Variable_2/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525635: I tensorflow/core/common_runtime/placer.cc:54] Variable_2/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525639: I tensorflow/core/common_runtime/placer.cc:54] Variable_3: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525642: I tensorflow/core/common_runtime/placer.cc:54] Variable_3/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525645: I tensorflow/core/common_runtime/placer.cc:54] Variable_3/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525648: I tensorflow/core/common_runtime/placer.cc:54] truncated_normal_2/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525652: I tensorflow/core/common_runtime/placer.cc:54] truncated_normal_2/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525655: I tensorflow/core/common_runtime/placer.cc:54] truncated_normal_2: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525659: I tensorflow/core/common_runtime/placer.cc:54] Variable_4: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525662: I tensorflow/core/common_runtime/placer.cc:54] Variable_4/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.525665: I tensorflow/core/common_runtime/placer.cc:54] Variable_4/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 14:56:07.
truediv: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# ...
# It: 96430, Loss: 1.070e-04, 1.070e-04
# It: 96440, Loss: 1.757e-04, 1.757e-04
# It: 96450, Loss: 1.803e-04, 1.803e-04
# It: 96460, Loss: 1.340e-04, 1.340e-04
# It: 96470, Loss: 1.711e-04, 1.711e-04
# It: 96480, Loss: 1.226e-04, 1.226e-04
# It: 96490, Loss: 1.980e-04, 1.980e-04
# It: 96500, Loss: 1.147e-04, 1.147e-04
# It: 96510, Loss: 2.217e-04, 2.217e-04
# It: 96520, Loss: 1.516e-04, 1.516e-04
# It: 96530, Loss: 1.232e-04, 1.232e-04
# It: 96540, Loss: 1.117e-04, 1.117e-04
# It: 96550, Loss: 2.249e-04, 2.249e-04
# It: 96560, Loss: 1.053e-04, 1.053e-04
# It: 96570, Loss: 1.435e-04, 1.435e-04
# It: 96580, Loss: 1.446e-04, 1.446e-04
# It: 96590, Loss: 1.353e-04, 1.353e-04
# It: 96600, Loss: 1.392e-04, 1.392e-04
# It: 96610, Loss: 1.361e-04, 1.361e-04
# It: 96620, Loss: 1.749e-04, 1.749e-04
# It: 96630, Loss: 1.089e-04, 1.089e-04
# It: 96640, Loss: 1.626e-04, 1.626e-04
# It: 96650, Loss: 1.178e-04, 1.178e-04
# It: 96660, Loss: 3.034e-04, 3.034e-04
# It: 96670, Loss: 1.603e-04, 1.603e-04
# It: 96680, Loss: 1.652e-04, 1.652e-04
# It: 96690, Loss: 1.179e-04, 1.179e-04
# It: 96700, Loss: 1.796e-04, 1.796e-04
# It: 96710, Loss: 1.274e-04, 1.274e-04
# It: 96720, Loss: 1.346e-04, 1.346e-04
# It: 96730, Loss: 1.984e-04, 1.984e-04
# It: 96740, Loss: 1.249e-04, 1.249e-04
# It: 96750, Loss: 2.635e-04, 2.635e-04
# It: 96760, Loss: 2.005e-04, 2.005e-04
# It: 96770, Loss: 2.058e-04, 2.058e-04
# It: 96780, Loss: 1.216e-04, 1.216e-04
# It: 96790, Loss: 1.642e-04, 1.642e-04
# It: 96800, Loss: 1.554e-04, 1.554e-04
# It: 96810, Loss: 1.298e-04, 1.298e-04
# It: 96820, Loss: 1.105e-04, 1.105e-04
# It: 96830, Loss: 2.141e-04, 2.141e-04
# It: 96840, Loss: 1.222e-04, 1.222e-04
# It: 96850, Loss: 2.109e-04, 2.109e-04
# It: 96860, Loss: 2.034e-04, 2.034e-04
# It: 96870, Loss: 1.551e-04, 1.551e-04
# It: 96880, Loss: 1.590e-04, 1.590e-04
# It: 96890, Loss: 1.397e-04, 1.397e-04
# It: 96900, Loss: 1.266e-04, 1.266e-04
# It: 96910, Loss: 1.735e-04, 1.735e-04
# It: 96920, Loss: 1.473e-04, 1.473e-04
# It: 96930, Loss: 2.071e-04, 2.071e-04
# It: 96940, Loss: 1.245e-04, 1.245e-04
# It: 96950, Loss: 1.465e-04, 1.465e-04
# It: 96960, Loss: 1.826e-04, 1.826e-04
# It: 96970, Loss: 1.764e-04, 1.764e-04
# It: 96980, Loss: 1.294e-04, 1.294e-04
# It: 96990, Loss: 2.339e-04, 2.339e-04
# It: 97000, Loss: 1.973e-04, 1.973e-04
# It: 97010, Loss: 1.532e-04, 1.532e-04
# It: 97020, Loss: 1.054e-04, 1.054e-04
# It: 97030, Loss: 1.471e-04, 1.471e-04
# It: 97040, Loss: 1.235e-04, 1.235e-04
# It: 97050, Loss: 1.629e-04, 1.629e-04
# It: 97060, Loss: 2.401e-04, 2.401e-04
# It: 97070, Loss: 1.267e-04, 1.267e-04
# It: 97080, Loss: 1.627e-04, 1.627e-04
# It: 97090, Loss: 1.332e-04, 1.332e-04
# It: 97100, Loss: 1.682e-04, 1.682e-04
# It: 97110, Loss: 1.425e-04, 1.425e-04
# It: 97120, Loss: 1.254e-04, 1.254e-04
# It: 97130, Loss: 2.429e-04, 2.429e-04
# It: 97140, Loss: 1.175e-04, 1.175e-04
# It: 97150, Loss: 1.179e-04, 1.179e-04
# It: 97160, Loss: 1.106e-04, 1.106e-04
# It: 97170, Loss: 1.711e-04, 1.711e-04
# It: 97180, Loss: 1.608e-04, 1.608e-04
# It: 97190, Loss: 1.253e-04, 1.253e-04
# It: 97200, Loss: 1.425e-04, 1.425e-04
# It: 97210, Loss: 1.509e-04, 1.509e-04
# It: 97220, Loss: 1.298e-04, 1.298e-04
# It: 97230, Loss: 1.592e-04, 1.592e-04
# It: 97240, Loss: 1.661e-04, 1.661e-04
# It: 97250, Loss: 1.680e-04, 1.680e-04
# It: 97260, Loss: 1.573e-04, 1.573e-04
# It: 97270, Loss: 1.442e-04, 1.442e-04
# It: 97280, Loss: 1.173e-04, 1.173e-04
# It: 97290, Loss: 2.173e-04, 2.173e-04
# It: 97300, Loss: 1.983e-04, 1.983e-04
# It: 97310, Loss: 1.042e-04, 1.042e-04
# It: 97320, Loss: 1.451e-04, 1.451e-04
# It: 97330, Loss: 2.085e-04, 2.085e-04
# It: 97340, Loss: 1.770e-04, 1.770e-04
# It: 97350, Loss: 1.976e-04, 1.976e-04
# It: 97360, Loss: 1.573e-04, 1.573e-04
# It: 97370, Loss: 1.495e-04, 1.495e-04
# It: 97380, Loss: 2.016e-04, 2.016e-04
# It: 97390, Loss: 1.889e-04, 1.889e-04
# It: 97400, Loss: 1.427e-04, 1.427e-04
# It: 97410, Loss: 1.804e-04, 1.804e-04
# It: 97420, Loss: 1.064e-04, 1.064e-04
# It: 97430, Loss: 1.050e-04, 1.050e-04
# It: 97440, Loss: 2.676e-04, 2.676e-04
# It: 97450, Loss: 1.147e-04, 1.147e-04
# It: 97460, Loss: 2.422e-04, 2.422e-04
# It: 97470, Loss: 1.178e-04, 1.178e-04
# It: 97480, Loss: 1.333e-04, 1.333e-04
# It: 97490, Loss: 1.631e-04, 1.631e-04
# It: 97500, Loss: 1.213e-04, 1.213e-04
# It: 97510, Loss: 1.359e-04, 1.359e-04
# It: 97520, Loss: 1.274e-04, 1.274e-04
# It: 97530, Loss: 1.399e-04, 1.399e-04
# It: 97540, Loss: 1.009e-04, 1.009e-04
# It: 97550, Loss: 1.559e-04, 1.559e-04
# It: 97560, Loss: 2.849e-04, 2.849e-04
# It: 97570, Loss: 1.417e-04, 1.417e-04
# It: 97580, Loss: 1.367e-04, 1.367e-04
# It: 97590, Loss: 1.140e-04, 1.140e-04
# It: 97600, Loss: 1.152e-04, 1.152e-04
# It: 97610, Loss: 1.186e-04, 1.186e-04
# It: 97620, Loss: 1.174e-04, 1.174e-04
# It: 97630, Loss: 2.903e-04, 2.903e-04
# It: 97640, Loss: 1.270e-04, 1.270e-04
# It: 97650, Loss: 1.486e-04, 1.486e-04
# It: 97660, Loss: 1.718e-04, 1.718e-04
# It: 97670, Loss: 1.089e-04, 1.089e-04
# It: 97680, Loss: 1.594e-04, 1.594e-04
# It: 97690, Loss: 1.374e-04, 1.374e-04
# It: 97700, Loss: 1.481e-04, 1.481e-04
# It: 97710, Loss: 1.221e-04, 1.221e-04
# It: 97720, Loss: 2.107e-04, 2.107e-04
# It: 97730, Loss: 1.154e-04, 1.154e-04
# It: 97740, Loss: 1.650e-04, 1.650e-04
# It: 97750, Loss: 1.332e-04, 1.332e-04
# It: 97760, Loss: 1.390e-04, 1.390e-04
# It: 97770, Loss: 2.269e-04, 2.269e-04
# It: 97780, Loss: 2.006e-04, 2.006e-04
# It: 97790, Loss: 1.437e-04, 1.437e-04
# It: 97800, Loss: 1.035e-04, 1.035e-04
# It: 97810, Loss: 1.316e-04, 1.316e-04
# It: 97820, Loss: 1.116e-04, 1.116e-04
# It: 97830, Loss: 1.054e-04, 1.054e-04
# It: 97840, Loss: 1.055e-04, 1.055e-04
# It: 97850, Loss: 1.992e-04, 1.992e-04
# It: 97860, Loss: 1.147e-04, 1.147e-04
# It: 97870, Loss: 1.335e-04, 1.335e-04
# It: 97880, Loss: 2.758e-04, 2.758e-04
# It: 97890, Loss: 1.718e-04, 1.718e-04
# It: 97900, Loss: 2.046e-04, 2.046e-04
# It: 97910, Loss: 1.281e-04, 1.281e-04
# It: 97920, Loss: 1.024e-04, 1.024e-04
# It: 97930, Loss: 1.410e-04, 1.410e-04
# It: 97940, Loss: 1.613e-04, 1.613e-04
# It: 97950, Loss: 1.518e-04, 1.518e-04
# It: 97960, Loss: 2.928e-04, 2.928e-04
# It: 97970, Loss: 1.037e-04, 1.037e-04
# It: 97980, Loss: 1.741e-04, 1.741e-04
# It: 97990, Loss: 1.937e-04, 1.937e-04
# It: 98000, Loss: 1.106e-04, 1.106e-04
# It: 98010, Loss: 1.486e-04, 1.486e-04
# It: 98020, Loss: 1.263e-04, 1.263e-04
# It: 98030, Loss: 1.445e-04, 1.445e-04
# It: 98040, Loss: 1.573e-04, 1.573e-04
# It: 98050, Loss: 1.406e-04, 1.406e-04
# It: 98060, Loss: 1.719e-04, 1.719e-04
# It: 98070, Loss: 1.148e-04, 1.148e-04
# It: 98080, Loss: 1.098e-04, 1.098e-04
# It: 98090, Loss: 5.624e-04, 5.624e-04
# It: 98100, Loss: 2.446e-04, 2.446e-04
# It: 98110, Loss: 2.221e-04, 2.221e-04
# It: 98120, Loss: 1.810e-04, 1.810e-04
# It: 98130, Loss: 1.555e-04, 1.555e-04
# It: 98140, Loss: 1.219e-04, 1.219e-04
# It: 98150, Loss: 1.303e-04, 1.303e-04
# It: 98160, Loss: 1.221e-04, 1.221e-04
# It: 98170, Loss: 1.360e-04, 1.360e-04
# It: 98180, Loss: 1.236e-04, 1.236e-04
# It: 98190, Loss: 1.338e-04, 1.338e-04
# It: 98200, Loss: 1.352e-04, 1.352e-04
# It: 98210, Loss: 1.225e-04, 1.225e-04
# It: 98220, Loss: 1.594e-04, 1.594e-04
# It: 98230, Loss: 1.298e-04, 1.298e-04
# It: 98240, Loss: 1.322e-04, 1.322e-04
# It: 98250, Loss: 2.509e-04, 2.509e-04
# It: 98260, Loss: 1.389e-04, 1.389e-04
# It: 98270, Loss: 1.622e-04, 1.622e-04
# It: 98280, Loss: 1.165e-04, 1.165e-04
# It: 98290, Loss: 1.374e-04, 1.374e-04
# It: 98300, Loss: 1.728e-04, 1.728e-04
# It: 98310, Loss: 1.970e-04, 1.970e-04
# It: 98320, Loss: 1.146e-04, 1.146e-04
# It: 98330, Loss: 1.658e-04, 1.658e-04
# It: 98340, Loss: 1.917e-04, 1.917e-04
# It: 98350, Loss: 1.418e-04, 1.418e-04
# It: 98360, Loss: 1.531e-04, 1.531e-04
# It: 98370, Loss: 1.899e-04, 1.899e-04
# It: 98380, Loss: 1.482e-04, 1.482e-04
# It: 98390, Loss: 1.630e-04, 1.630e-04
# It: 98400, Loss: 1.076e-04, 1.076e-04
# It: 98410, Loss: 1.314e-04, 1.314e-04
# It: 98420, Loss: 1.113e-04, 1.113e-04
# It: 98430, Loss: 1.435e-04, 1.435e-04
# It: 98440, Loss: 1.227e-04, 1.227e-04
# It: 98450, Loss: 2.009e-04, 2.009e-04
# It: 98460, Loss: 1.152e-04, 1.152e-04
# It: 98470, Loss: 2.012e-04, 2.012e-04
# It: 98480, Loss: 1.595e-04, 1.595e-04
# It: 98490, Loss: 1.324e-04, 1.324e-04
# It: 98500, Loss: 1.319e-04, 1.319e-04
# It: 98510, Loss: 1.759e-04, 1.759e-04
# It: 98520, Loss: 1.366e-04, 1.366e-04
# It: 98530, Loss: 2.682e-04, 2.682e-04
# It: 98540, Loss: 1.103e-04, 1.103e-04
# It: 98550, Loss: 1.917e-04, 1.917e-04
# It: 98560, Loss: 1.119e-04, 1.119e-04
# It: 98570, Loss: 2.072e-04, 2.072e-04
# It: 98580, Loss: 1.540e-04, 1.540e-04
# It: 98590, Loss: 1.117e-04, 1.117e-04
# It: 98600, Loss: 1.916e-04, 1.916e-04
# It: 98610, Loss: 1.723e-04, 1.723e-04
# It: 98620, Loss: 1.893e-04, 1.893e-04
# It: 98630, Loss: 1.859e-04, 1.859e-04
# It: 98640, Loss: 1.323e-04, 1.323e-04
# It: 98650, Loss: 1.385e-04, 1.385e-04
# It: 98660, Loss: 1.187e-04, 1.187e-04
# It: 98670, Loss: 1.190e-04, 1.190e-04
# It: 98680, Loss: 1.913e-04, 1.913e-04
# It: 98690, Loss: 1.605e-04, 1.605e-04
# It: 98700, Loss: 1.272e-04, 1.272e-04
# It: 98710, Loss: 1.732e-04, 1.732e-04
# It: 98720, Loss: 2.192e-04, 2.192e-04
# It: 98730, Loss: 1.371e-04, 1.371e-04
# It: 98740, Loss: 1.037e-04, 1.037e-04
# It: 98750, Loss: 1.795e-04, 1.795e-04
# It: 98760, Loss: 2.293e-04, 2.293e-04
# It: 98770, Loss: 1.424e-04, 1.424e-04
# It: 98780, Loss: 1.196e-04, 1.196e-04
# It: 98790, Loss: 1.208e-04, 1.208e-04
# It: 98800, Loss: 1.127e-04, 1.127e-04
# It: 98810, Loss: 1.560e-04, 1.560e-04
# It: 98820, Loss: 2.513e-04, 2.513e-04
# It: 98830, Loss: 1.992e-04, 1.992e-04
# It: 98840, Loss: 1.342e-04, 1.342e-04
# It: 98850, Loss: 1.100e-04, 1.100e-04
# It: 98860, Loss: 2.009e-04, 2.009e-04
# It: 98870, Loss: 1.500e-04, 1.500e-04
# It: 98880, Loss: 1.852e-04, 1.852e-04
# It: 98890, Loss: 1.799e-04, 1.799e-04
# It: 98900, Loss: 1.799e-04, 1.799e-04
# It: 98910, Loss: 1.862e-04, 1.862e-04
# It: 98920, Loss: 1.509e-04, 1.509e-04
# It: 98930, Loss: 1.847e-04, 1.847e-04
# It: 98940, Loss: 1.335e-04, 1.335e-04
# It: 98950, Loss: 1.305e-04, 1.305e-04
# It: 98960, Loss: 1.302e-04, 1.302e-04
# It: 98970, Loss: 1.030e-04, 1.030e-04
# It: 98980, Loss: 1.482e-04, 1.482e-04
# It: 98990, Loss: 1.944e-04, 1.944e-04
# It: 99000, Loss: 2.260e-04, 2.260e-04
# It: 99010, Loss: 1.393e-04, 1.393e-04
# It: 99020, Loss: 1.925e-04, 1.925e-04
# It: 99030, Loss: 1.523e-04, 1.523e-04
# It: 99040, Loss: 2.087e-04, 2.087e-04
# It: 99050, Loss: 1.104e-04, 1.104e-04
# It: 99060, Loss: 1.866e-04, 1.866e-04
# It: 99070, Loss: 2.026e-04, 2.026e-04
# It: 99080, Loss: 1.681e-04, 1.681e-04
# It: 99090, Loss: 1.903e-04, 1.903e-04
# It: 99100, Loss: 1.259e-04, 1.259e-04
# It: 99110, Loss: 1.368e-04, 1.368e-04
# It: 99120, Loss: 1.260e-04, 1.260e-04
# It: 99130, Loss: 9.960e-05, 9.960e-05
# It: 99140, Loss: 1.803e-04, 1.803e-04
# It: 99150, Loss: 1.428e-04, 1.428e-04
# It: 99160, Loss: 1.862e-04, 1.862e-04
# It: 99170, Loss: 1.481e-04, 1.481e-04
# It: 99180, Loss: 1.214e-04, 1.214e-04
# It: 99190, Loss: 1.119e-04, 1.119e-04
# It: 99200, Loss: 1.475e-04, 1.475e-04
# It: 99210, Loss: 1.725e-04, 1.725e-04
# It: 99220, Loss: 2.783e-04, 2.783e-04
# It: 99230, Loss: 1.607e-04, 1.607e-04
# It: 99240, Loss: 1.026e-04, 1.026e-04
# It: 99250, Loss: 1.252e-04, 1.252e-04
# It: 99260, Loss: 1.085e-04, 1.085e-04
# It: 99270, Loss: 1.151e-04, 1.151e-04
# It: 99280, Loss: 1.283e-04, 1.283e-04
# It: 99290, Loss: 2.474e-04, 2.474e-04
# It: 99300, Loss: 2.215e-04, 2.215e-04
# It: 99310, Loss: 1.184e-04, 1.184e-04
# It: 99320, Loss: 2.867e-04, 2.867e-04
# It: 99330, Loss: 1.287e-04, 1.287e-04
# It: 99340, Loss: 1.323e-04, 1.323e-04
# It: 99350, Loss: 1.162e-04, 1.162e-04
# It: 99360, Loss: 1.858e-04, 1.858e-04
# It: 99370, Loss: 1.758e-04, 1.758e-04
# It: 99380, Loss: 1.247e-04, 1.247e-04
# It: 99390, Loss: 1.211e-04, 1.211e-04
# It: 99400, Loss: 1.123e-04, 1.123e-04
# It: 99410, Loss: 1.305e-04, 1.305e-04
# It: 99420, Loss: 1.418e-04, 1.418e-04
# It: 99430, Loss: 5.984e-04, 5.984e-04
# It: 99440, Loss: 2.121e-04, 2.121e-04
# It: 99450, Loss: 1.492e-04, 1.492e-04
# It: 99460, Loss: 1.401e-04, 1.401e-04
# It: 99470, Loss: 1.252e-04, 1.252e-04
# It: 99480, Loss: 1.189e-04, 1.189e-04
# It: 99490, Loss: 1.299e-04, 1.299e-04
# It: 99500, Loss: 2.134e-04, 2.134e-04
# It: 99510, Loss: 1.429e-04, 1.429e-04
# It: 99520, Loss: 1.131e-04, 1.131e-04
# It: 99530, Loss: 1.423e-04, 1.423e-04
# It: 99540, Loss: 2.497e-04, 2.497e-04
# It: 99550, Loss: 1.287e-04, 1.287e-04
# It: 99560, Loss: 1.625e-04, 1.625e-04
# It: 99570, Loss: 2.332e-04, 2.332e-04
# It: 99580, Loss: 1.188e-04, 1.188e-04
# It: 99590, Loss: 1.293e-04, 1.293e-04
# It: 99600, Loss: 1.976e-04, 1.976e-04
# It: 99610, Loss: 1.645e-04, 1.645e-04
# It: 99620, Loss: 1.161e-04, 1.161e-04
# It: 99630, Loss: 1.759e-04, 1.759e-04
# It: 99640, Loss: 1.083e-04, 1.083e-04
# It: 99650, Loss: 1.621e-04, 1.621e-04
# It: 99660, Loss: 1.147e-04, 1.147e-04
# It: 99670, Loss: 1.752e-04, 1.752e-04
# It: 99680, Loss: 1.263e-04, 1.263e-04
# It: 99690, Loss: 1.489e-04, 1.489e-04
# It: 99700, Loss: 1.902e-04, 1.902e-04
# It: 99710, Loss: 1.912e-04, 1.912e-04
# It: 99720, Loss: 1.486e-04, 1.486e-04
# It: 99730, Loss: 1.475e-04, 1.475e-04
# It: 99740, Loss: 1.924e-04, 1.924e-04
# It: 99750, Loss: 1.466e-04, 1.466e-04
# It: 99760, Loss: 1.780e-04, 1.780e-04
# It: 99770, Loss: 1.313e-04, 1.313e-04
# It: 99780, Loss: 1.334e-04, 1.334e-04
# It: 99790, Loss: 1.683e-04, 1.683e-04
# It: 99800, Loss: 2.698e-04, 2.698e-04
# It: 99810, Loss: 1.167e-04, 1.167e-04
# It: 99820, Loss: 1.560e-04, 1.560e-04
# It: 99830, Loss: 1.187e-04, 1.187e-04
# It: 99840, Loss: 1.153e-04, 1.153e-04
# It: 99850, Loss: 1.316e-04, 1.316e-04
# It: 99860, Loss: 2.831e-04, 2.831e-04
# It: 99870, Loss: 1.118e-04, 1.118e-04
# It: 99880, Loss: 1.690e-04, 1.690e-04
# It: 99890, Loss: 1.148e-04, 1.148e-04
# It: 99900, Loss: 1.958e-04, 1.958e-04
# It: 99910, Loss: 2.074e-04, 2.074e-04
# It: 99920, Loss: 1.555e-04, 1.555e-04
# It: 99930, Loss: 1.497e-04, 1.497e-04
# It: 99940, Loss: 1.290e-04, 1.290e-04
# It: 99950, Loss: 3.000e-04, 3.000e-04
# It: 99960, Loss: 1.246e-04, 1.246e-04
# It: 99970, Loss: 1.495e-04, 1.495e-04
# It: 99980, Loss: 1.378e-04, 1.378e-04
# It: 99990, Loss: 1.521e-04, 1.521e-04
# 1 th iterations, Loss: 0.0001365912175970152
# 2 th iterations, Loss: 0.6272537112236023
# 3 th iterations, Loss: 0.38583073019981384
# 4 th iterations, Loss: 0.00010491375724086538
# 5 th iterations, Loss: 0.0001014702720567584
# 6 th iterations, Loss: 9.926236816681921e-05
# 7 th iterations, Loss: 9.687415149528533e-05
# 8 th iterations, Loss: 9.484565089223906e-05
# 9 th iterations, Loss: 9.455460531171411e-05
# 10 th iterations, Loss: 9.421665163245052e-05
# 11 th iterations, Loss: 9.403549483977258e-05
# 12 th iterations, Loss: 9.397015674039721e-05
# 13 th iterations, Loss: 9.38536977628246e-05
# 14 th iterations, Loss: 9.37642835197039e-05
# 15 th iterations, Loss: 9.382853750139475e-05
# 16 th iterations, Loss: 9.379289986100048e-05
# 17 th iterations, Loss: 9.38348748604767e-05
# 18 th iterations, Loss: 9.37677250476554e-05
# 19 th iterations, Loss: 9.376286470796913e-05
# 20 th iterations, Loss: 9.376286470796913e-05
# 21 th iterations, Loss: 9.375595254823565e-05
# 22 th iterations, Loss: 9.375595254823565e-05
# 23 th iterations, Loss: 9.375617082696408e-05
# 24 th iterations, Loss: 9.375595254823565e-05
# 25 th iterations, Loss: 9.382588905282319e-05
# 26 th iterations, Loss: 9.377968672197312e-05
# 27 th iterations, Loss: 9.379099356010556e-05
# 28 th iterations, Loss: 9.37669537961483e-05
# 29 th iterations, Loss: 9.375752415508032e-05
# 30 th iterations, Loss: 9.375595254823565e-05
# 31 th iterations, Loss: 9.375595254823565e-05
# 32 th iterations, Loss: 9.375595254823565e-05
# 33 th iterations, Loss: 9.375595254823565e-05
# 34 th iterations, Loss: 9.375595254823565e-05
# 35 th iterations, Loss: 9.375595254823565e-05
# 36 th iterations, Loss: 9.375595254823565e-05
# 37 th iterations, Loss: 9.375595254823565e-05
# 38 th iterations, Loss: 9.375595254823565e-05
# 39 th iterations, Loss: 9.375595254823565e-05
# 40 th iterations, Loss: 9.375595254823565e-05
# 41 th iterations, Loss: 9.375595254823565e-05
# 42 th iterations, Loss: 9.375595254823565e-05
# 43 th iterations, Loss: 9.375595254823565e-05
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000094
#   Number of iterations: 13
#   Number of functions evaluations: 43
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000094
#   Number of iterations: 13
#   Number of functions evaluations: 43
# Save NN parameters successfully...
