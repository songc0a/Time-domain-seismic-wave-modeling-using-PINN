# %%
import numpy as np
import time
from pyDOE import lhs
import matplotlib
# matplotlib.use('Agg')
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import shutil
import pickle
import math
import scipy.io

# Setup GPU for training (use tensorflow v1.9 for CuDNNLSTM)
import tensorflow as tf
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'  # CPU:-1; GPU0: 1; GPU1: 0;
np.random.seed(1111)
tf.compat.v1.set_random_seed(1111)
# Out:
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# 2022-10-21 15:47:38.285530: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.

# %%
misfit = []
misfit1 = []
class DeepHPM:
    # Initialize the class
    def __init__(self, Collo, snap1, snap2, snap3, vp, uv_layers, lb, ub, ExistModel=0, modelDir=''):

        # Count for callback function
        self.count = 0
        self.vp = vp

        
        self.lb = lb
        self.ub = ub
        self.loss_f_rec = []
        self.loss_snap_rec=[]
        self.loss_rec=[]
        self.train_loss=[]
   

        # Collocation point
        self.x_c = Collo[:, 0:1]
        self.y_c = Collo[:, 1:2]
        self.t_c = Collo[:, 2:3]

        self.x_snap1 = snap1[:, 0:1]
        self.y_snap1 = snap1[:, 1:2]
        self.t_snap1 = snap1[:, 2:3]
        self.u_snap1 = snap1[:, 3:4]
        
        self.x_snap2 = snap2[:, 0:1]
        self.y_snap2 = snap2[:, 1:2]
        self.t_snap2 = snap2[:, 2:3]
        self.u_snap2 = snap2[:, 3:4]
        
        self.x_snap3 = snap3[:, 0:1]
        self.y_snap3 = snap3[:, 1:2]
        self.t_snap3 = snap3[:, 2:3]
        self.u_snap3 = snap3[:, 3:4]
        
     
        # Define layers
        self.uv_layers = uv_layers

        # Initialize NNs
        if ExistModel== 0 :
            self.uv_weights, self.uv_biases = self.initialize_NN(self.uv_layers)
        else:
            self.uv_weights, self.uv_biases = self.load_NN(modelDir, self.uv_layers)
        # tf placeholders
        self.learning_rate = tf.placeholder(tf.float32, shape=[])
        self.x_tf = tf.placeholder(tf.float32, shape=[None, self.x_c.shape[1]])    # Point for postprocessing
        self.y_tf = tf.placeholder(tf.float32, shape=[None, self.y_c.shape[1]])
        self.t_tf = tf.placeholder(tf.float32, shape=[None, self.t_c.shape[1]])

        self.x_c_tf = tf.placeholder(tf.float32, shape=[None, self.x_c.shape[1]])
        self.y_c_tf = tf.placeholder(tf.float32, shape=[None, self.y_c.shape[1]])
        self.t_c_tf = tf.placeholder(tf.float32, shape=[None, self.t_c.shape[1]])

        self.x_snap1_tf = tf.placeholder(tf.float32, shape=[None, self.x_snap1.shape[1]])
        self.y_snap1_tf = tf.placeholder(tf.float32, shape=[None, self.y_snap1.shape[1]])
        self.t_snap1_tf = tf.placeholder(tf.float32, shape=[None, self.t_snap1.shape[1]])
        self.u_snap1_tf = tf.placeholder(tf.float32, shape=[None, self.u_snap1.shape[1]])

        self.x_snap2_tf = tf.placeholder(tf.float32, shape=[None, self.x_snap2.shape[1]])
        self.y_snap2_tf = tf.placeholder(tf.float32, shape=[None, self.y_snap2.shape[1]])
        self.t_snap2_tf = tf.placeholder(tf.float32, shape=[None, self.t_snap2.shape[1]])
        self.u_snap2_tf = tf.placeholder(tf.float32, shape=[None, self.u_snap2.shape[1]])
        
        self.x_snap3_tf = tf.placeholder(tf.float32, shape=[None, self.x_snap3.shape[1]])
        self.y_snap3_tf = tf.placeholder(tf.float32, shape=[None, self.y_snap3.shape[1]])
        self.t_snap3_tf = tf.placeholder(tf.float32, shape=[None, self.t_snap3.shape[1]])
        self.u_snap3_tf = tf.placeholder(tf.float32, shape=[None, self.u_snap3.shape[1]])
 

        # tf graphs
        self.u_pred = self.net_uv(self.x_tf, self.y_tf, self.t_tf)
        self.u_snap2_pred  = self.net_uv(self.x_snap2_tf, self.y_snap2_tf, self.t_snap2_tf)
        self.u_snap1_pred  = self.net_uv(self.x_snap1_tf, self.y_snap1_tf, self.t_snap1_tf)
        self.u_snap3_pred  = self.net_uv(self.x_snap3_tf, self.y_snap3_tf, self.t_snap3_tf)
 
      
        self.f_pred_u = self.net_f_sig(self.x_c_tf, self.y_c_tf, self.t_c_tf)

        self.loss_f = tf.reduce_mean(tf.square(self.f_pred_u)) 
    
        self.loss_snap = tf.reduce_mean(tf.square(self.u_snap1_pred - self.u_snap1_tf)) \
                         + tf.reduce_mean(tf.square(self.u_snap2_pred - self.u_snap2_tf))\
                         + tf.reduce_mean(tf.square(self.u_snap3_pred - self.u_snap3_tf)) 
        
        self.loss = self.loss_snap + 1e-4 * self.loss_f
        #self.loss = self.loss_snap + 1e-3 * self.loss_f #for next training
        

        # Optimizer for solution
        self.optimizer = tf.contrib.opt.ScipyOptimizerInterface(self.loss,
                                                                var_list=self.uv_weights + self.uv_biases,
                                                                method='L-BFGS-B',
                                                                options={'maxiter': 20000,
                                                                         'maxfun': 20000,
                                                                         'maxcor': 50,
                                                                         'maxls': 50,
                                                                         'ftol': 1 * np.finfo(float).eps})

        self.optimizer_Adam = tf.train.AdamOptimizer(learning_rate=self.learning_rate)
        self.train_op_Adam = self.optimizer_Adam.minimize(self.loss,
                                                          var_list=self.uv_weights + self.uv_biases)

        # tf session
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        init = tf.global_variables_initializer()
        self.sess.run(init)

    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)


    def save_NN(self, fileDir):
        uv_weights = self.sess.run(self.uv_weights)
        uv_biases = self.sess.run(self.uv_biases)
        with open(fileDir, 'wb') as f:
            # pickle.dump([np.array(uv_weights), np.array(uv_biases)], f)
            pickle.dump([uv_weights, uv_biases], f)
            print("Save NN parameters successfully...")

    def load_NN(self, fileDir, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        with open(fileDir, 'rb') as f:
            uv_weights, uv_biases = pickle.load(f)
            # print(len(uv_weights))
            # print(np.shape(uv_weights))
            # print(num_layers)

            # Stored model must has the same # of layers
            assert num_layers == (len(uv_weights)+1)

            for num in range(0, num_layers - 1):
                W = tf.Variable(uv_weights[num])
                b = tf.Variable(uv_biases[num])
                weights.append(W)
                biases.append(b)
                print("Load NN parameters successfully...")
        return weights, biases

    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1
        # H = X
        H = 2.0 * (X - self.lb) / (self.ub - self.lb) - 1.0
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.sin(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

    def net_uv(self, x, y, t):
        # This NN return sigma_phi
        u = self.neural_net(tf.concat([x, y, t], 1), self.uv_weights, self.uv_biases)
        u = u[:, 0:1]
        #ut = tf.gradients(u, t)[0]
        return u 

    def net_f_sig(self, x, y, t):
        
        vp =self.vp         
        u = self.net_uv(x, y, t)
        ut = tf.gradients(u, t)[0]
        u_tt = tf.gradients(ut, t)[0]

        u_x = tf.gradients(u, x)[0]
        u_y = tf.gradients(u, y)[0]
        u_xx = tf.gradients(u_x, x)[0]
        u_yy = tf.gradients(u_y, y)[0]

        f_u = u_tt - vp*vp*(u_xx + u_yy)
        return f_u

    def callback(self, loss):
        self.count = self.count + 1
        print('{} th iterations, Loss: {}'.format(self.count, loss))
        self.train_loss.append(loss)

    def train(self, iter, learning_rate, batch_num):


        loss_f = []
        loss_snap = []
        loss = []

        # The collocation point is splited into partitions of batch_num，1 epoch for training
        for i in range(batch_num):
            col_num = self.x_c.shape[0]
            idx_start = int(i * col_num / batch_num)
            idx_end = int((i + 1) * col_num / batch_num)

            tf_dict = {self.x_c_tf: self.x_c[idx_start:idx_end,:], self.y_c_tf: self.y_c[idx_start:idx_end,:], self.t_c_tf: self.t_c[idx_start:idx_end,:],
                       self.x_snap1_tf: self.x_snap1, self.y_snap1_tf: self.y_snap1, self.t_snap1_tf: self.t_snap1, self.u_snap1_tf: self.u_snap1,
                       self.x_snap2_tf: self.x_snap2, self.y_snap2_tf: self.y_snap2, self.t_snap2_tf: self.t_snap2, self.u_snap2_tf: self.u_snap2, 
                       self.x_snap3_tf: self.x_snap3, self.y_snap3_tf: self.y_snap3, self.t_snap3_tf: self.t_snap3, self.u_snap3_tf: self.u_snap3,self.learning_rate: learning_rate}

            for it in range(iter):

                self.sess.run(self.train_op_Adam, tf_dict)

                # Print
                if it % 10 == 0:
                    loss_value = self.sess.run(self.loss, tf_dict)
                    loss_f_value = self.sess.run(self.loss_f, tf_dict)
                    loss_snap_value = self.sess.run(self.loss_snap, tf_dict)
                    print('It: %d, Loss: %.3e, %.3e, %.3e' %
                          (it, loss_value, loss_snap_value,loss_f_value))

                self.loss_f_rec.append(self.sess.run(self.loss_f, tf_dict))
                self.loss_snap_rec.append(self.sess.run(self.loss_snap, tf_dict))
                self.loss_rec.append(self.sess.run(self.loss, tf_dict))

        return self.loss, self.loss_snap, self.loss_f

    def train_bfgs(self, batch_num):
        # The collocation point is splited into partitions of batch_num
        for i in range(batch_num):
            col_num = self.x_c.shape[0]
            idx_start = int(i*col_num/batch_num)
            idx_end = int((i+1)*col_num/batch_num)
            tf_dict = {self.x_c_tf: self.x_c[idx_start:idx_end,:], self.y_c_tf: self.y_c[idx_start:idx_end,:], self.t_c_tf: self.t_c[idx_start:idx_end,:],
                       #self.x_IC_tf: self.x_IC, self.y_IC_tf: self.y_IC, self.t_IC_tf: self.t_IC,
                       self.x_snap1_tf: self.x_snap1, self.y_snap1_tf: self.y_snap1, self.t_snap1_tf: self.t_snap1, self.u_snap1_tf: self.u_snap1,
                       self.x_snap2_tf: self.x_snap2, self.y_snap2_tf: self.y_snap2, self.t_snap2_tf: self.t_snap2, self.u_snap2_tf: self.u_snap2,
                       self.x_snap3_tf: self.x_snap3, self.y_snap3_tf: self.y_snap3, self.t_snap3_tf: self.t_snap3, self.u_snap3_tf: self.u_snap3}

            self.optimizer.minimize(self.sess,
                                    feed_dict=tf_dict,
                                    fetches=[self.loss],
                                    loss_callback=self.callback)

    def predict(self, x_star, y_star, t_star):
        u_star = self.sess.run(self.u_pred, {self.x_tf: x_star, self.y_tf: y_star, self.t_tf: t_star})
        return u_star

    def probe(self, x_star, y_star, t_star):
        u_star = self.sess.run(self.u_pred, {self.x_tf: x_star, self.y_tf: y_star, self.t_tf: t_star})      
        return u_star
    
    def getloss(self):  # To be updated

        tf_dict = {self.x_c_tf: self.x_c, self.y_c_tf: self.y_c, self.t_c_tf: self.t_c,
                   self.x_snap1_tf: self.x_snap1, self.y_snap1_tf: self.y_snap1, self.t_snap1_tf: self.t_snap1, self.u_snap1_tf: self.u_snap1,
                   self.x_snap2_tf: self.x_snap2, self.y_snap2_tf: self.y_snap2, self.t_snap2_tf: self.t_snap2, self.u_snap2_tf: self.u_snap2,
                   self.x_snap3_tf: self.x_snap3, self.y_snap3_tf: self.y_snap3, self.t_snap3_tf: self.t_snap3, self.u_snap3_tf: self.u_snap3}

        loss_f = self.sess.run(self.loss_f, tf_dict)
        loss_snap = self.sess.run(self.loss_snap, tf_dict)
        loss = self.sess.run(self.loss, tf_dict)
       
        return loss, loss_snap ,loss_f

# %%
if __name__ == "__main__":

    # Need pretraining!! (i.e. train for 10s -> 15s -> 25s)

    MAX_T = 1.2
    # Domain bounds
    lb = np.array([0.0, 0.0, 0.2])
    ub = np.array([2, 2, MAX_T])
    lb_sam = np.array([0.0, 0.5, 0.5])
    ub_sam = np.array([2, 1.5, MAX_T])

    # Network configuration
    uv_layers = [3] + 5*[64] + 3*[32]  + [1]

    # Num of collocation point in x, y, t
    N_f = 80000
    
    data_snap1 = scipy.io.loadmat('./ceng_zs0/u_t2.mat')
    data_snap2 = scipy.io.loadmat('./ceng_zs0/u_t4.mat')
    data_snap3 = scipy.io.loadmat('./ceng_zs0/u_t7.mat')
  
    u_snap1 = data_snap1['u_t0'].flatten()[:, None] 
    u_snap2 = data_snap2['u_t0'].flatten()[:, None]
    x_snap1 =  data_snap1['xx'].flatten()[:, None]
    y_snap1 =  data_snap1['zz'].flatten()[:, None]
    x_snap2 =  data_snap2['xx'].flatten()[:, None]
    y_snap2 =  data_snap2['zz'].flatten()[:, None]
    
    u_snap3 = data_snap3['u_t0'].flatten()[:, None] 
    x_snap3 =  data_snap3['xx'].flatten()[:, None]
    y_snap3 =  data_snap3['zz'].flatten()[:, None]
   
    t_snap1 = np.zeros((x_snap1.size, 1))
    t_snap1.fill(0.2)
    t_snap2 = np.zeros((x_snap2.size, 1))
    t_snap2.fill(0.3)
    t_snap3 = np.zeros((x_snap3.size, 1))
    t_snap3.fill(0.7)
    
    snap1 = np.concatenate((x_snap1, y_snap1, t_snap1, u_snap1), 1)
    snap2 = np.concatenate((x_snap2, y_snap2, t_snap2, u_snap2), 1)
    snap3 = np.concatenate((x_snap3, y_snap3, t_snap3, u_snap3), 1)
  
    N = x_snap1.shape[0]
    N_train = round(N/4*4)   
 # Training Data    
    idx = np.random.choice(N, N_train, replace=False)

    snap1_train = snap1[idx,:]
    snap2_train = snap2[idx,:]
    snap3_train = snap3[idx,:]

    # Collocation point
    XYT = lb + (ub - lb) * lhs(3, N_f)
    XYT_c_sam = lb_sam + (ub_sam - lb_sam) * lhs(3, 30000)
    XYT_c = np.concatenate((XYT, XYT_c_sam), 0)
    vp = XYT_c[:,0:1]*0

    A = XYT_c[:,0:1]
    B = XYT_c[:,1:2]    
        
        
    for i in range(len(vp)):
        if B[i]<1:
            vp[i]=1.5
        else:
            vp[i]=1.9

    with tf.device('/device:GPU:0'):

        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        session = tf.Session(config=config)

        model = DeepHPM(XYT_c, snap1_train, snap2_train, snap3_train,  vp, uv_layers, lb, ub, ExistModel=1, modelDir='uv_NN_cengpre.pickle')

        loss_snap, loss_f,loss = model.train(iter=60000, learning_rate=5e-4, batch_num=1)
        model.train_bfgs(batch_num=1)

        model.save_NN('uv_NN_ceng_3snap.pickle')

        model.getloss()
        
        loss_f_history = model.loss_f_rec
        scipy.io.savemat('loss_f_history_train.mat',{'loss_f_history':loss_f_history})
        
        loss_snap_history = model.loss_snap_rec
        scipy.io.savemat('loss_snap_history_train.mat',{'loss_snap_history':loss_snap_history})
        
        loss_adam_history = model.loss_rec
        scipy.io.savemat('loss_adam_history.mat',{'loss_adam_history':loss_adam_history})
        
        loss_lbfgs_history = model.train_loss
        scipy.io.savemat('loss_lbfgs_history.mat',{'loss_lbfgs_history':loss_lbfgs_history})
        
        train_losshistory = np.concatenate((model.loss_rec,model.train_loss),0)
        scipy.io.savemat('loss_adam+lbfgs.mat',{'train_losshistory':train_losshistory})

        # Output result at each time step
        x_star = np.linspace(0.0, 2, 101)
        y_star = np.linspace(0.0, 2, 101)
        x_star, y_star = np.meshgrid(x_star, y_star)
        x_star = x_star.flatten()[:, None]
        y_star = y_star.flatten()[:, None]
      
        shutil.rmtree('./output', ignore_errors=True)
        os.makedirs('./output')
        
        t_star_4 = np.zeros((x_star.size, 1))
        t_star_4.fill(0.4)
        u_pred_4 = model.predict(x_star, y_star, t_star_4)
        
        t_star_5 = np.zeros((x_star.size, 1))
        t_star_5.fill(0.5)
        u_pred_5 = model.predict(x_star, y_star, t_star_5)
        
        t_star_6 = np.zeros((x_star.size, 1))
        t_star_6.fill(0.6)
        u_pred_6 = model.predict(x_star, y_star, t_star_6)
        
        t_star_9 = np.zeros((x_star.size, 1))
        t_star_9.fill(0.9)
        u_pred_9 = model.predict(x_star, y_star, t_star_9)
        
        t_star_10 = np.zeros((x_star.size, 1))
        t_star_10.fill(1)
        u_pred_10 = model.predict(x_star, y_star, t_star_10)
        
        t_star_11 = np.zeros((x_star.size, 1))
        t_star_11.fill(1.1)
        u_pred_11 = model.predict(x_star, y_star, t_star_11)
        
    
    scipy.io.savemat('u_pred_4.mat',{'u_pred_4':u_pred_4})
    scipy.io.savemat('u_pred_5.mat',{'u_pred_5':u_pred_5})
    scipy.io.savemat('u_pred_6.mat',{'u_pred_6':u_pred_6})
    
    scipy.io.savemat('u_pred_9.mat',{'u_pred_9':u_pred_9})
    scipy.io.savemat('u_pred_10.mat',{'u_pred_10':u_pred_10})
    
    scipy.io.savemat('u_pred_11.mat',{'u_pred_11':u_pred_11})
   
    fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(21, 14))
    fig.subplots_adjust(hspace=0.15, wspace=0.1)
    
    uu1=ax[0,0].scatter(x_star, y_star, c=u_pred_9,cmap = ('seismic'),vmin=-1.5, vmax=1.5)
    ax[0, 0].set_xticks([])
    ax[0, 0].set_yticks([])
    ax[0, 0].set_title('TD-PINN t=0.9s', fontsize=22)
    cbar = fig.colorbar(uu1, orientation='vertical', ax=ax[0, 0], fraction=0.046, pad=0.04)
    cbar.ax.tick_params(labelsize=12)
    #plt.colorbar(uu1)
    
 
    
    uu4=ax[0,1].scatter(x_star, y_star, c=u_pred_10,cmap = ('seismic'),vmin=-1.5, vmax=1.5)
    ax[0, 1].set_xticks([])
    ax[0, 1].set_yticks([])
    ax[0, 1].set_title('TD-PINN t=1.0s', fontsize=22)
    cbar = fig.colorbar(uu4, orientation='vertical', ax=ax[0, 1], fraction=0.046, pad=0.04)
    cbar.ax.tick_params(labelsize=12)
    
 
    uu7=ax[0,2].scatter(x_star, y_star, c=u_pred_11,cmap = ('seismic'),vmin=-1.5, vmax=1.5)
    ax[0, 2].set_xticks([])
    ax[0, 2].set_yticks([])
    ax[0, 2].set_title('TD-PINN t=1.1s', fontsize=22)
    cbar = fig.colorbar(uu7, orientation='vertical', ax=ax[0, 2], fraction=0.046, pad=0.04)
    cbar.ax.tick_params(labelsize=12)
    
  
    
    plt.show()
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_175/1333523507.py:75: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# WARNING:tensorflow:From /tmp/ipykernel_175/1333523507.py:75: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# WARNING:tensorflow:From /tmp/ipykernel_175/1333523507.py:77: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# WARNING:tensorflow:From /tmp/ipykernel_175/1333523507.py:77: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2022-10-21 15:47:47.791150: I tensorflow/core/platform/cpu_feature_guard.cc:145] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX
# 2022-10-21 15:47:47.804607: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2600000000 Hz
# 2022-10-21 15:47:47.809379: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5636b0cc5590 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-10-21 15:47:47.809398: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-10-21 15:47:47.810555: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-10-21 15:47:47.836869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1666] Found device 0 with properties:
# name: NVIDIA GeForce RTX 3090 major: 8 minor: 6 memoryClockRate(GHz): 1.695
# pciBusID: 0000:52:00.0
# 2022-10-21 15:47:47.836901: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-21 15:47:47.841496: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-10-21 15:47:47.843682: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-21 15:47:47.844012: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-21 15:47:47.844539: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2022-10-21 15:47:47.845487: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-10-21 15:47:47.845626: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-10-21 15:47:47.846373: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1794] Adding visible gpu devices: 0
# 2022-10-21 15:47:47.846411: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Load NN parameters successfully...
# Load NN parameters successfully...
# Load NN parameters successfully...
# Load NN parameters successfully...
# Load NN parameters successfully...
# Load NN parameters successfully...
# Load NN parameters successfully...
# Load NN parameters successfully...
# Load NN parameters successfully...
# WARNING:tensorflow:From /tmp/ipykernel_175/5338516.py:51: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2022-10-21 15:47:48.307932: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1206] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-21 15:47:48.307960: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212]      0
# 2022-10-21 15:47:48.307965: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1225] 0:   N
# 2022-10-21 15:47:48.309416: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1351] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22088 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:52:00.0, compute capability: 8.6)
# 2022-10-21 15:47:48.311768: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5636c2a263d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-10-21 15:47:48.311782: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# WARNING:tensorflow:From /tmp/ipykernel_175/5338516.py:51: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# WARNING:tensorflow:From /tmp/ipykernel_175/5338516.py:107: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From /tmp/ipykernel_175/5338516.py:107: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:52:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
#
# WARNING:tensorflow:From /tmp/ipykernel_175/5338516.py:114: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# 2022-10-21 15:47:54.264583: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1666] Found device 0 with properties:
# name: NVIDIA GeForce RTX 3090 major: 8 minor: 6 memoryClockRate(GHz): 1.695
# pciBusID: 0000:52:00.0
# 2022-10-21 15:47:54.264651: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-21 15:47:54.264667: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-10-21 15:47:54.264676: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-21 15:47:54.264685: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-21 15:47:54.264693: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2022-10-21 15:47:54.264701: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-10-21 15:47:54.264710: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-10-21 15:47:54.265366: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1794] Adding visible gpu devices: 0
# 2022-10-21 15:47:54.265392: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1206] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-21 15:47:54.265396: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212]      0
# 2022-10-21 15:47:54.265399: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1225] 0:   N
# 2022-10-21 15:47:54.266058: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1351] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22088 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:52:00.0, compute capability: 8.6)
# WARNING:tensorflow:From /tmp/ipykernel_175/5338516.py:114: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2022-10-21 15:47:54.471675: I tensorflow/core/common_runtime/placer.cc:54] Variable: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471710: I tensorflow/core/common_runtime/placer.cc:54] Variable/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471715: I tensorflow/core/common_runtime/placer.cc:54] Variable/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471720: I tensorflow/core/common_runtime/placer.cc:54] Variable_1: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471724: I tensorflow/core/common_runtime/placer.cc:54] Variable_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471727: I tensorflow/core/common_runtime/placer.cc:54] Variable_1/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471732: I tensorflow/core/common_runtime/placer.cc:54] Variable_2: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471736: I tensorflow/core/common_runtime/placer.cc:54] Variable_2/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471739: I tensorflow/core/common_runtime/placer.cc:54] Variable_2/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471743: I tensorflow/core/common_runtime/placer.cc:54] Variable_3: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471746: I tensorflow/core/common_runtime/placer.cc:54] Variable_3/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471749: I tensorflow/core/common_runtime/placer.cc:54] Variable_3/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471753: I tensorflow/core/common_runtime/placer.cc:54] Variable_4: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471757: I tensorflow/core/common_runtime/placer.cc:54] Variable_4/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471760: I tensorflow/core/common_runtime/placer.cc:54] Variable_4/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471764: I tensorflow/core/common_runtime/placer.cc:54] Variable_5: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471767: I tensorflow/core/common_runtime/placer.cc:54] Variable_5/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471770: I tensorflow/core/common_runtime/placer.cc:54] Variable_5/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471774: I tensorflow/core/common_runtime/placer.cc:54] Variable_6: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471779: I tensorflow/core/common_runtime/placer.cc:54] Variable_6/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471782: I tensorflow/core/common_runtime/placer.cc:54] Variable_6/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471786: I tensorflow/core/common_runtime/placer.cc:54] Variable_7: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471789: I tensorflow/core/common_runtime/placer.cc:54] Variable_7/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471792: I tensorflow/core/common_runtime/placer.cc:54] Variable_7/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471796: I tensorflow/core/common_runtime/placer.cc:54] Variable_8: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471800: I tensorflow/core/common_runtime/placer.cc:54] Variable_8/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471803: I tensorflow/core/common_runtime/placer.cc:54] Variable_8/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471806: I tensorflow/core/common_runtime/placer.cc:54] Variable_9: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471812: I tensorflow/core/common_runtime/placer.cc:54] Variable_9/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471815: I tensorflow/core/common_runtime/placer.cc:54] Variable_9/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471819: I tensorflow/core/common_runtime/placer.cc:54] Variable_10: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471823: I tensorflow/core/common_runtime/placer.cc:54] Variable_10/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471827: I tensorflow/core/common_runtime/placer.cc:54] Variable_10/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471830: I tensorflow/core/common_runtime/placer.cc:54] Variable_11: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471834: I tensorflow/core/common_runtime/placer.cc:54] Variable_11/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471837: I tensorflow/core/common_runtime/placer.cc:54] Variable_11/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471840: I tensorflow/core/common_runtime/placer.cc:54] Variable_12: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471844: I tensorflow/core/common_runtime/placer.cc:54] Variable_12/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471847: I tensorflow/core/common_runtime/placer.cc:54] Variable_12/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471851: I tensorflow/core/common_runtime/placer.cc:54] Variable_13: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471855: I tensorflow/core/common_runtime/placer.cc:54] Variable_13/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471858: I tensorflow/core/common_runtime/placer.cc:54] Variable_13/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471862: I tensorflow/core/common_runtime/placer.cc:54] Variable_14: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471866: I tensorflow/core/common_runtime/placer.cc:54] Variable_14/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471869: I tensorflow/core/common_runtime/placer.cc:54] Variable_14/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471872: I tensorflow/core/common_runtime/placer.cc:54] Variable_15: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471876: I tensorflow/core/common_runtime/placer.cc:54] Variable_15/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471878: I tensorflow/core/common_runtime/placer.cc:54] Variable_15/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471882: I tensorflow/core/common_runtime/placer.cc:54] Variable_16: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471886: I tensorflow/core/common_runtime/placer.cc:54] Variable_16/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471889: I tensorflow/core/common_runtime/placer.cc:54] Variable_16/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471900: I tensorflow/core/common_runtime/placer.cc:54] Variable_17: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471904: I tensorflow/core/common_runtime/placer.cc:54] Variable_17/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471907: I tensorflow/core/common_runtime/placer.cc:54] Variable_17/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471912: I tensorflow/core/common_runtime/placer.cc:54] concat: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471918: I tensorflow/core/common_runtime/placer.cc:54] sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471923: I tensorflow/core/common_runtime/placer.cc:54] mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471927: I tensorflow/core/common_runtime/placer.cc:54] truediv: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471931: I tensorflow/core/common_runtime/placer.cc:54] sub_1: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471935: I tensorflow/core/common_runtime/placer.cc:54] MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471939: I tensorflow/core/common_runtime/placer.cc:54] Add: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471943: I tensorflow/core/common_runtime/placer.cc:54] Sin: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471947: I tensorflow/core/common_runtime/placer.cc:54] MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471951: I tensorflow/core/common_runtime/placer.cc:54] Add_1: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471955: I tensorflow/core/common_runtime/placer.cc:54] Sin_1: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471959: I tensorflow/core/common_runtime/placer.cc:54] MatMul_2: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471963: I tensorflow/core/common_runtime/placer.cc:54] Add_2: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471966: I tensorflow/core/common_runtime/placer.cc:54] Sin_2: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471970: I tensorflow/core/common_runtime/placer.cc:54] MatMul_3: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471974: I tensorflow/core/common_runtime/placer.cc:54] Add_3: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471977: I tensorflow/core/common_runtime/placer.cc:54] Sin_3: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471981: I tensorflow/core/common_runtime/placer.cc:54] MatMul_4: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471985: I tensorflow/core/common_runtime/placer.cc:54] Add_4: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471989: I tensorflow/core/common_runtime/placer.cc:54] Sin_4: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471993: I tensorflow/core/common_runtime/placer.cc:54] MatMul_5: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.471996: I tensorflow/core/common_runtime/placer.cc:54] Add_5: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472000: I tensorflow/core/common_runtime/placer.cc:54] Sin_5: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472004: I tensorflow/core/common_runtime/placer.cc:54] MatMul_6: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472008: I tensorflow/core/common_runtime/placer.cc:54] Add_6: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472012: I tensorflow/core/common_runtime/placer.cc:54] Sin_6: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472016: I tensorflow/core/common_runtime/placer.cc:54] MatMul_7: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472019: I tensorflow/core/common_runtime/placer.cc:54] Add_7: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472023: I tensorflow/core/common_runtime/placer.cc:54] Sin_7: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472027: I tensorflow/core/common_runtime/placer.cc:54] MatMul_8: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472030: I tensorflow/core/common_runtime/placer.cc:54] Add_8: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472036: I tensorflow/core/common_runtime/placer.cc:54] strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472040: I tensorflow/core/common_runtime/placer.cc:54] concat_1: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472044: I tensorflow/core/common_runtime/placer.cc:54] sub_2: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472048: I tensorflow/core/common_runtime/placer.cc:54] mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472052: I tensorflow/core/common_runtime/placer.cc:54] truediv_1: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472056: I tensorflow/core/common_runtime/placer.cc:54] sub_3: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472060: I tensorflow/core/common_runtime/placer.cc:54] MatMul_9: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472064: I tensorflow/core/common_runtime/placer.cc:54] Add_9: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472068: I tensorflow/core/common_runtime/placer.cc:54] Sin_8: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472071: I tensorflow/core/common_runtime/placer.cc:54] MatMul_10: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472076: I tensorflow/core/common_runtime/placer.cc:54] Add_10: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472080: I tensorflow/core/common_runtime/placer.cc:54] Sin_9: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472083: I tensorflow/core/common_runtime/placer.cc:54] MatMul_11: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472087: I tensorflow/core/common_runtime/placer.cc:54] Add_11: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472091: I tensorflow/core/common_runtime/placer.cc:54] Sin_10: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472094: I tensorflow/core/common_runtime/placer.cc:54] MatMul_12: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472098: I tensorflow/core/common_runtime/placer.cc:54] Add_12: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472102: I tensorflow/core/common_runtime/placer.cc:54] Sin_11: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472106: I tensorflow/core/common_runtime/placer.cc:54] MatMul_13: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472110: I tensorflow/core/common_runtime/placer.cc:54] Add_13: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472114: I tensorflow/core/common_runtime/placer.cc:54] Sin_12: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472117: I tensorflow/core/common_runtime/placer.cc:54] MatMul_14: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472121: I tensorflow/core/common_runtime/placer.cc:54] Add_14: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472125: I tensorflow/core/common_runtime/placer.cc:54] Sin_13: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472129: I tensorflow/core/common_runtime/placer.cc:54] MatMul_15: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472133: I tensorflow/core/common_runtime/placer.cc:54] Add_15: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472137: I tensorflow/core/common_runtime/placer.cc:54] Sin_14: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472141: I tensorflow/core/common_runtime/placer.cc:54] MatMul_16: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472144: I tensorflow/core/common_runtime/placer.cc:54] Add_16: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472150: I tensorflow/core/common_runtime/placer.cc:54] Sin_15: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472154: I tensorflow/core/common_runtime/placer.cc:54] MatMul_17: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472158: I tensorflow/core/common_runtime/placer.cc:54] Add_17: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472164: I tensorflow/core/common_runtime/placer.cc:54] strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472168: I tensorflow/core/common_runtime/placer.cc:54] concat_2: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472173: I tensorflow/core/common_runtime/placer.cc:54] sub_4: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472177: I tensorflow/core/common_runtime/placer.cc:54] mul_2: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472180: I tensorflow/core/common_runtime/placer.cc:54] truediv_2: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472184: I tensorflow/core/common_runtime/placer.cc:54] sub_5: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472188: I tensorflow/core/common_runtime/placer.cc:54] MatMul_18: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472192: I tensorflow/core/common_runtime/placer.cc:54] Add_18: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472196: I tensorflow/core/common_runtime/placer.cc:54] Sin_16: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472200: I tensorflow/core/common_runtime/placer.cc:54] MatMul_19: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472204: I tensorflow/core/common_runtime/placer.cc:54] Add_19: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472208: I tensorflow/core/common_runtime/placer.cc:54] Sin_17: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472211: I tensorflow/core/common_runtime/placer.cc:54] MatMul_20: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472215: I tensorflow/core/common_runtime/placer.cc:54] Add_20: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472219: I tensorflow/core/common_runtime/placer.cc:54] Sin_18: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472223: I tensorflow/core/common_runtime/placer.cc:54] MatMul_21: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472226: I tensorflow/core/common_runtime/placer.cc:54] Add_21: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472231: I tensorflow/core/common_runtime/placer.cc:54] Sin_19: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472235: I tensorflow/core/common_runtime/placer.cc:54] MatMul_22: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472238: I tensorflow/core/common_runtime/placer.cc:54] Add_22: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472242: I tensorflow/core/common_runtime/placer.cc:54] Sin_20: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472246: I tensorflow/core/common_runtime/placer.cc:54] MatMul_23: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472250: I tensorflow/core/common_runtime/placer.cc:54] Add_23: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472253: I tensorflow/core/common_runtime/placer.cc:54] Sin_21: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472257: I tensorflow/core/common_runtime/placer.cc:54] MatMul_24: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472261: I tensorflow/core/common_runtime/placer.cc:54] Add_24: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472267: I tensorflow/core/common_runtime/placer.cc:54] Sin_22: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472271: I tensorflow/core/common_runtime/placer.cc:54] MatMul_25: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472274: I tensorflow/core/common_runtime/placer.cc:54] Add_25: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472278: I tensorflow/core/common_runtime/placer.cc:54] Sin_23: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472282: I tensorflow/core/common_runtime/placer.cc:54] MatMul_26: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472286: I tensorflow/core/common_runtime/placer.cc:54] Add_26: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472290: I tensorflow/core/common_runtime/placer.cc:54] strided_slice_2: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472294: I tensorflow/core/common_runtime/placer.cc:54] concat_3: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472297: I tensorflow/core/common_runtime/placer.cc:54] sub_6: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472301: I tensorflow/core/common_runtime/placer.cc:54] mul_3: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472306: I tensorflow/core/common_runtime/placer.cc:54] truediv_3: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472309: I tensorflow/core/common_runtime/placer.cc:54] sub_7: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472313: I tensorflow/core/common_runtime/placer.cc:54] MatMul_27: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472317: I tensorflow/core/common_runtime/placer.cc:54] Add_27: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472321: I tensorflow/core/common_runtime/placer.cc:54] Sin_24: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472325: I tensorflow/core/common_runtime/placer.cc:54] MatMul_28: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472329: I tensorflow/core/common_runtime/placer.cc:54] Add_28: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472333: I tensorflow/core/common_runtime/placer.cc:54] Sin_25: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472336: I tensorflow/core/common_runtime/placer.cc:54] MatMul_29: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472340: I tensorflow/core/common_runtime/placer.cc:54] Add_29: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472344: I tensorflow/core/common_runtime/placer.cc:54] Sin_26: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472347: I tensorflow/core/common_runtime/placer.cc:54] MatMul_30: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472351: I tensorflow/core/common_runtime/placer.cc:54] Add_30: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472355: I tensorflow/core/common_runtime/placer.cc:54] Sin_27: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472359: I tensorflow/core/common_runtime/placer.cc:54] MatMul_31: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472363: I tensorflow/core/common_runtime/placer.cc:54] Add_31: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472367: I tensorflow/core/common_runtime/placer.cc:54] Sin_28: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472371: I tensorflow/core/common_runtime/placer.cc:54] MatMul_32: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472375: I tensorflow/core/common_runtime/placer.cc:54] Add_32: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472380: I tensorflow/core/common_runtime/placer.cc:54] Sin_29: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472383: I tensorflow/core/common_runtime/placer.cc:54] MatMul_33: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472387: I tensorflow/core/common_runtime/placer.cc:54] Add_33: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472391: I tensorflow/core/common_runtime/placer.cc:54] Sin_30: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472395: I tensorflow/core/common_runtime/placer.cc:54] MatMul_34: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472399: I tensorflow/core/common_runtime/placer.cc:54] Add_34: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472402: I tensorflow/core/common_runtime/placer.cc:54] Sin_31: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472406: I tensorflow/core/common_runtime/placer.cc:54] MatMul_35: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472410: I tensorflow/core/common_runtime/placer.cc:54] Add_35: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472414: I tensorflow/core/common_runtime/placer.cc:54] strided_slice_3: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472420: I tensorflow/core/common_runtime/placer.cc:54] concat_4: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472424: I tensorflow/core/common_runtime/placer.cc:54] sub_8: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472428: I tensorflow/core/common_runtime/placer.cc:54] mul_4: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472432: I tensorflow/core/common_runtime/placer.cc:54] truediv_4: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472436: I tensorflow/core/common_runtime/placer.cc:54] sub_9: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472439: I tensorflow/core/common_runtime/placer.cc:54] MatMul_36: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472443: I tensorflow/core/common_runtime/placer.cc:54] Add_36: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472447: I tensorflow/core/common_runtime/placer.cc:54] Sin_32: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472451: I tensorflow/core/common_runtime/placer.cc:54] MatMul_37: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472455: I tensorflow/core/common_runtime/placer.cc:54] Add_37: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472459: I tensorflow/core/common_runtime/placer.cc:54] Sin_33: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472462: I tensorflow/core/common_runtime/placer.cc:54] MatMul_38: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472466: I tensorflow/core/common_runtime/placer.cc:54] Add_38: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472470: I tensorflow/core/common_runtime/placer.cc:54] Sin_34: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472474: I tensorflow/core/common_runtime/placer.cc:54] MatMul_39: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472478: I tensorflow/core/common_runtime/placer.cc:54] Add_39: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472481: I tensorflow/core/common_runtime/placer.cc:54] Sin_35: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472486: I tensorflow/core/common_runtime/placer.cc:54] MatMul_40: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472489: I tensorflow/core/common_runtime/placer.cc:54] Add_40: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472494: I tensorflow/core/common_runtime/placer.cc:54] Sin_36: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472498: I tensorflow/core/common_runtime/placer.cc:54] MatMul_41: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472502: I tensorflow/core/common_runtime/placer.cc:54] Add_41: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472506: I tensorflow/core/common_runtime/placer.cc:54] Sin_37: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472510: I tensorflow/core/common_runtime/placer.cc:54] MatMul_42: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472514: I tensorflow/core/common_runtime/placer.cc:54] Add_42: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472518: I tensorflow/core/common_runtime/placer.cc:54] Sin_38: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472522: I tensorflow/core/common_runtime/placer.cc:54] MatMul_43: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472526: I tensorflow/core/common_runtime/placer.cc:54] Add_43: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472530: I tensorflow/core/common_runtime/placer.cc:54] Sin_39: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472533: I tensorflow/core/common_runtime/placer.cc:54] MatMul_44: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472537: I tensorflow/core/common_runtime/placer.cc:54] Add_44: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472541: I tensorflow/core/common_runtime/placer.cc:54] strided_slice_4: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472547: I tensorflow/core/common_runtime/placer.cc:54] gradients/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472551: I tensorflow/core/common_runtime/placer.cc:54] gradients/Fill: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472555: I tensorflow/core/common_runtime/placer.cc:54] gradients/strided_slice_4_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472559: I tensorflow/core/common_runtime/placer.cc:54] gradients/strided_slice_4_grad/StridedSliceGrad: (StridedSliceGrad): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472563: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_44_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472567: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_44_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472571: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_44_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472575: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_44_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472579: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_44_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472583: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_44_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472587: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_44_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472591: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_44_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472594: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_44_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472598: I tensorflow/core/common_runtime/placer.cc:54] gradients/Sin_39_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472603: I tensorflow/core/common_runtime/placer.cc:54] gradients/Sin_39_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472607: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_43_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472611: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_43_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472616: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_43_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472620: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_43_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472624: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_43_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472628: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_43_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472631: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_43_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472635: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_43_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472639: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_43_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472644: I tensorflow/core/common_runtime/placer.cc:54] gradients/Sin_38_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472648: I tensorflow/core/common_runtime/placer.cc:54] gradients/Sin_38_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472653: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_42_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472656: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_42_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472660: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_42_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472664: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_42_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472667: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_42_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472671: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_42_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472675: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_42_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472679: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_42_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472683: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_42_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472687: I tensorflow/core/common_runtime/placer.cc:54] gradients/Sin_37_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472691: I tensorflow/core/common_runtime/placer.cc:54] gradients/Sin_37_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472695: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_41_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472698: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_41_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472702: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_41_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472706: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_41_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472710: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_41_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472715: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_41_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472718: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_41_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472722: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_41_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472726: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_41_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472730: I tensorflow/core/common_runtime/placer.cc:54] gradients/Sin_36_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472734: I tensorflow/core/common_runtime/placer.cc:54] gradients/Sin_36_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472738: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_40_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472742: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_40_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472746: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_40_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472750: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_40_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472753: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_40_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472757: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_40_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472761: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_40_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472765: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_40_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472768: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_40_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472772: I tensorflow/core/common_runtime/placer.cc:54] gradients/Sin_35_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472777: I tensorflow/core/common_runtime/placer.cc:54] gradients/Sin_35_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472781: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_39_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2022-10-21 15:47:54.472785: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_39_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# ...
# It: 57150, Loss: 2.472e-02, 1.460e-02, 1.012e+02
# It: 57160, Loss: 2.340e-02, 1.453e-02, 8.876e+01
# It: 57170, Loss: 2.301e-02, 1.451e-02, 8.505e+01
# It: 57180, Loss: 2.350e-02, 1.458e-02, 8.920e+01
# It: 57190, Loss: 2.263e-02, 1.443e-02, 8.205e+01
# It: 57200, Loss: 2.274e-02, 1.450e-02, 8.238e+01
# It: 57210, Loss: 2.478e-02, 1.451e-02, 1.027e+02
# It: 57220, Loss: 2.420e-02, 1.456e-02, 9.638e+01
# It: 57230, Loss: 2.285e-02, 1.446e-02, 8.387e+01
# It: 57240, Loss: 2.315e-02, 1.443e-02, 8.718e+01
# It: 57250, Loss: 2.219e-02, 1.437e-02, 7.817e+01
# It: 57260, Loss: 2.454e-02, 1.444e-02, 1.009e+02
# It: 57270, Loss: 2.597e-02, 1.461e-02, 1.135e+02
# It: 57280, Loss: 2.415e-02, 1.444e-02, 9.704e+01
# It: 57290, Loss: 2.476e-02, 1.478e-02, 9.984e+01
# It: 57300, Loss: 2.270e-02, 1.444e-02, 8.256e+01
# It: 57310, Loss: 2.235e-02, 1.441e-02, 7.937e+01
# It: 57320, Loss: 2.629e-02, 1.442e-02, 1.187e+02
# It: 57330, Loss: 2.550e-02, 1.447e-02, 1.103e+02
# It: 57340, Loss: 2.449e-02, 1.449e-02, 1.001e+02
# It: 57350, Loss: 2.262e-02, 1.450e-02, 8.120e+01
# It: 57360, Loss: 2.280e-02, 1.449e-02, 8.307e+01
# It: 57370, Loss: 2.264e-02, 1.446e-02, 8.185e+01
# It: 57380, Loss: 2.429e-02, 1.450e-02, 9.792e+01
# It: 57390, Loss: 2.502e-02, 1.452e-02, 1.049e+02
# It: 57400, Loss: 2.291e-02, 1.451e-02, 8.406e+01
# It: 57410, Loss: 2.312e-02, 1.445e-02, 8.670e+01
# It: 57420, Loss: 2.238e-02, 1.444e-02, 7.938e+01
# It: 57430, Loss: 2.388e-02, 1.440e-02, 9.480e+01
# It: 57440, Loss: 2.341e-02, 1.446e-02, 8.957e+01
# It: 57450, Loss: 2.255e-02, 1.444e-02, 8.109e+01
# It: 57460, Loss: 2.351e-02, 1.461e-02, 8.899e+01
# It: 57470, Loss: 2.312e-02, 1.441e-02, 8.711e+01
# It: 57480, Loss: 2.272e-02, 1.442e-02, 8.304e+01
# It: 57490, Loss: 2.321e-02, 1.439e-02, 8.820e+01
# It: 57500, Loss: 2.269e-02, 1.443e-02, 8.258e+01
# It: 57510, Loss: 2.297e-02, 1.440e-02, 8.573e+01
# It: 57520, Loss: 2.327e-02, 1.444e-02, 8.831e+01
# It: 57530, Loss: 2.390e-02, 1.447e-02, 9.433e+01
# It: 57540, Loss: 2.357e-02, 1.440e-02, 9.170e+01
# It: 57550, Loss: 2.356e-02, 1.448e-02, 9.080e+01
# It: 57560, Loss: 2.563e-02, 1.455e-02, 1.108e+02
# It: 57570, Loss: 2.451e-02, 1.445e-02, 1.007e+02
# It: 57580, Loss: 2.334e-02, 1.450e-02, 8.837e+01
# It: 57590, Loss: 2.548e-02, 1.458e-02, 1.090e+02
# It: 57600, Loss: 2.344e-02, 1.439e-02, 9.048e+01
# It: 57610, Loss: 2.239e-02, 1.441e-02, 7.978e+01
# It: 57620, Loss: 2.304e-02, 1.446e-02, 8.574e+01
# It: 57630, Loss: 2.335e-02, 1.441e-02, 8.944e+01
# It: 57640, Loss: 2.280e-02, 1.441e-02, 8.387e+01
# It: 57650, Loss: 2.367e-02, 1.443e-02, 9.235e+01
# It: 57660, Loss: 2.621e-02, 1.437e-02, 1.183e+02
# It: 57670, Loss: 2.646e-02, 1.453e-02, 1.193e+02
# It: 57680, Loss: 2.490e-02, 1.444e-02, 1.046e+02
# It: 57690, Loss: 2.409e-02, 1.462e-02, 9.464e+01
# It: 57700, Loss: 2.274e-02, 1.449e-02, 8.250e+01
# It: 57710, Loss: 2.371e-02, 1.458e-02, 9.128e+01
# It: 57720, Loss: 2.284e-02, 1.441e-02, 8.428e+01
# It: 57730, Loss: 2.310e-02, 1.441e-02, 8.688e+01
# It: 57740, Loss: 2.308e-02, 1.447e-02, 8.613e+01
# It: 57750, Loss: 2.696e-02, 1.443e-02, 1.253e+02
# It: 57760, Loss: 2.665e-02, 1.471e-02, 1.194e+02
# It: 57770, Loss: 2.425e-02, 1.443e-02, 9.818e+01
# It: 57780, Loss: 2.389e-02, 1.448e-02, 9.406e+01
# It: 57790, Loss: 2.410e-02, 1.450e-02, 9.602e+01
# It: 57800, Loss: 2.277e-02, 1.443e-02, 8.338e+01
# It: 57810, Loss: 2.292e-02, 1.446e-02, 8.457e+01
# It: 57820, Loss: 2.747e-02, 1.438e-02, 1.309e+02
# It: 57830, Loss: 2.498e-02, 1.447e-02, 1.051e+02
# It: 57840, Loss: 2.327e-02, 1.442e-02, 8.848e+01
# It: 57850, Loss: 2.245e-02, 1.442e-02, 8.038e+01
# It: 57860, Loss: 2.268e-02, 1.440e-02, 8.282e+01
# It: 57870, Loss: 2.329e-02, 1.443e-02, 8.863e+01
# It: 57880, Loss: 2.344e-02, 1.437e-02, 9.067e+01
# It: 57890, Loss: 2.652e-02, 1.449e-02, 1.203e+02
# It: 57900, Loss: 2.507e-02, 1.447e-02, 1.060e+02
# It: 57910, Loss: 2.575e-02, 1.443e-02, 1.132e+02
# It: 57920, Loss: 2.385e-02, 1.443e-02, 9.421e+01
# It: 57930, Loss: 2.422e-02, 1.450e-02, 9.720e+01
# It: 57940, Loss: 2.239e-02, 1.439e-02, 7.999e+01
# It: 57950, Loss: 2.238e-02, 1.438e-02, 8.000e+01
# It: 57960, Loss: 2.545e-02, 1.454e-02, 1.090e+02
# It: 57970, Loss: 2.407e-02, 1.446e-02, 9.612e+01
# It: 57980, Loss: 2.249e-02, 1.436e-02, 8.132e+01
# It: 57990, Loss: 2.311e-02, 1.437e-02, 8.741e+01
# It: 58000, Loss: 2.504e-02, 1.448e-02, 1.056e+02
# It: 58010, Loss: 2.461e-02, 1.469e-02, 9.918e+01
# It: 58020, Loss: 2.563e-02, 1.456e-02, 1.107e+02
# It: 58030, Loss: 2.636e-02, 1.445e-02, 1.191e+02
# It: 58040, Loss: 2.415e-02, 1.449e-02, 9.664e+01
# It: 58050, Loss: 2.265e-02, 1.442e-02, 8.224e+01
# It: 58060, Loss: 2.462e-02, 1.448e-02, 1.014e+02
# It: 58070, Loss: 2.322e-02, 1.436e-02, 8.861e+01
# It: 58080, Loss: 2.351e-02, 1.444e-02, 9.074e+01
# It: 58090, Loss: 2.302e-02, 1.439e-02, 8.627e+01
# It: 58100, Loss: 2.462e-02, 1.452e-02, 1.009e+02
# It: 58110, Loss: 2.292e-02, 1.439e-02, 8.537e+01
# It: 58120, Loss: 2.250e-02, 1.437e-02, 8.135e+01
# It: 58130, Loss: 2.586e-02, 1.464e-02, 1.122e+02
# It: 58140, Loss: 2.337e-02, 1.448e-02, 8.888e+01
# It: 58150, Loss: 2.499e-02, 1.440e-02, 1.059e+02
# It: 58160, Loss: 2.442e-02, 1.442e-02, 9.994e+01
# It: 58170, Loss: 2.413e-02, 1.439e-02, 9.740e+01
# It: 58180, Loss: 2.276e-02, 1.435e-02, 8.410e+01
# It: 58190, Loss: 2.445e-02, 1.434e-02, 1.011e+02
# It: 58200, Loss: 2.232e-02, 1.433e-02, 7.987e+01
# It: 58210, Loss: 2.312e-02, 1.436e-02, 8.755e+01
# It: 58220, Loss: 2.282e-02, 1.434e-02, 8.477e+01
# It: 58230, Loss: 2.315e-02, 1.430e-02, 8.849e+01
# It: 58240, Loss: 2.222e-02, 1.433e-02, 7.890e+01
# It: 58250, Loss: 2.596e-02, 1.439e-02, 1.158e+02
# It: 58260, Loss: 2.251e-02, 1.433e-02, 8.179e+01
# It: 58270, Loss: 2.391e-02, 1.434e-02, 9.571e+01
# It: 58280, Loss: 2.232e-02, 1.433e-02, 7.991e+01
# It: 58290, Loss: 2.343e-02, 1.440e-02, 9.029e+01
# It: 58300, Loss: 2.298e-02, 1.435e-02, 8.626e+01
# It: 58310, Loss: 2.281e-02, 1.434e-02, 8.474e+01
# It: 58320, Loss: 2.523e-02, 1.441e-02, 1.082e+02
# It: 58330, Loss: 2.251e-02, 1.435e-02, 8.154e+01
# It: 58340, Loss: 2.531e-02, 1.438e-02, 1.093e+02
# It: 58350, Loss: 2.417e-02, 1.453e-02, 9.642e+01
# It: 58360, Loss: 2.318e-02, 1.445e-02, 8.729e+01
# It: 58370, Loss: 2.291e-02, 1.435e-02, 8.566e+01
# It: 58380, Loss: 2.379e-02, 1.444e-02, 9.353e+01
# It: 58390, Loss: 2.315e-02, 1.439e-02, 8.761e+01
# It: 58400, Loss: 2.276e-02, 1.433e-02, 8.431e+01
# It: 58410, Loss: 2.438e-02, 1.457e-02, 9.816e+01
# It: 58420, Loss: 2.542e-02, 1.440e-02, 1.103e+02
# It: 58430, Loss: 2.281e-02, 1.433e-02, 8.487e+01
# It: 58440, Loss: 2.506e-02, 1.458e-02, 1.048e+02
# It: 58450, Loss: 2.797e-02, 1.444e-02, 1.354e+02
# It: 58460, Loss: 2.504e-02, 1.445e-02, 1.060e+02
# It: 58470, Loss: 2.629e-02, 1.472e-02, 1.156e+02
# It: 58480, Loss: 2.401e-02, 1.448e-02, 9.531e+01
# It: 58490, Loss: 2.352e-02, 1.441e-02, 9.118e+01
# It: 58500, Loss: 2.225e-02, 1.439e-02, 7.858e+01
# It: 58510, Loss: 2.242e-02, 1.440e-02, 8.021e+01
# It: 58520, Loss: 2.253e-02, 1.430e-02, 8.227e+01
# It: 58530, Loss: 2.335e-02, 1.438e-02, 8.975e+01
# It: 58540, Loss: 2.574e-02, 1.463e-02, 1.111e+02
# It: 58550, Loss: 2.821e-02, 1.454e-02, 1.367e+02
# It: 58560, Loss: 2.527e-02, 1.454e-02, 1.073e+02
# It: 58570, Loss: 2.631e-02, 1.464e-02, 1.167e+02
# It: 58580, Loss: 2.270e-02, 1.450e-02, 8.200e+01
# It: 58590, Loss: 2.273e-02, 1.442e-02, 8.302e+01
# It: 58600, Loss: 2.255e-02, 1.436e-02, 8.186e+01
# It: 58610, Loss: 2.219e-02, 1.433e-02, 7.856e+01
# It: 58620, Loss: 2.388e-02, 1.439e-02, 9.487e+01
# It: 58630, Loss: 2.244e-02, 1.436e-02, 8.072e+01
# It: 58640, Loss: 2.322e-02, 1.438e-02, 8.838e+01
# It: 58650, Loss: 2.497e-02, 1.438e-02, 1.059e+02
# It: 58660, Loss: 2.434e-02, 1.456e-02, 9.785e+01
# It: 58670, Loss: 2.624e-02, 1.446e-02, 1.179e+02
# It: 58680, Loss: 2.293e-02, 1.444e-02, 8.491e+01
# It: 58690, Loss: 2.276e-02, 1.443e-02, 8.334e+01
# It: 58700, Loss: 2.324e-02, 1.451e-02, 8.733e+01
# It: 58710, Loss: 2.238e-02, 1.431e-02, 8.065e+01
# It: 58720, Loss: 2.499e-02, 1.461e-02, 1.038e+02
# It: 58730, Loss: 2.338e-02, 1.449e-02, 8.891e+01
# It: 58740, Loss: 2.275e-02, 1.436e-02, 8.390e+01
# It: 58750, Loss: 2.377e-02, 1.451e-02, 9.266e+01
# It: 58760, Loss: 2.350e-02, 1.438e-02, 9.126e+01
# It: 58770, Loss: 2.426e-02, 1.435e-02, 9.917e+01
# It: 58780, Loss: 2.329e-02, 1.444e-02, 8.851e+01
# It: 58790, Loss: 2.245e-02, 1.429e-02, 8.159e+01
# It: 58800, Loss: 2.348e-02, 1.442e-02, 9.058e+01
# It: 58810, Loss: 2.380e-02, 1.437e-02, 9.428e+01
# It: 58820, Loss: 2.460e-02, 1.442e-02, 1.018e+02
# It: 58830, Loss: 2.308e-02, 1.447e-02, 8.613e+01
# It: 58840, Loss: 2.230e-02, 1.434e-02, 7.953e+01
# It: 58850, Loss: 2.318e-02, 1.437e-02, 8.809e+01
# It: 58860, Loss: 2.787e-02, 1.440e-02, 1.348e+02
# It: 58870, Loss: 2.287e-02, 1.447e-02, 8.402e+01
# It: 58880, Loss: 2.472e-02, 1.451e-02, 1.021e+02
# It: 58890, Loss: 2.349e-02, 1.431e-02, 9.180e+01
# It: 58900, Loss: 2.280e-02, 1.438e-02, 8.421e+01
# It: 58910, Loss: 2.292e-02, 1.442e-02, 8.504e+01
# It: 58920, Loss: 2.279e-02, 1.435e-02, 8.437e+01
# It: 58930, Loss: 2.408e-02, 1.437e-02, 9.710e+01
# It: 58940, Loss: 2.675e-02, 1.450e-02, 1.225e+02
# It: 58950, Loss: 2.324e-02, 1.445e-02, 8.791e+01
# It: 58960, Loss: 2.466e-02, 1.445e-02, 1.021e+02
# It: 58970, Loss: 2.280e-02, 1.429e-02, 8.509e+01
# It: 58980, Loss: 2.361e-02, 1.437e-02, 9.248e+01
# It: 58990, Loss: 2.439e-02, 1.427e-02, 1.012e+02
# It: 59000, Loss: 2.368e-02, 1.434e-02, 9.341e+01
# It: 59010, Loss: 2.349e-02, 1.432e-02, 9.166e+01
# It: 59020, Loss: 2.506e-02, 1.436e-02, 1.071e+02
# It: 59030, Loss: 2.342e-02, 1.440e-02, 9.029e+01
# It: 59040, Loss: 2.349e-02, 1.444e-02, 9.051e+01
# It: 59050, Loss: 2.331e-02, 1.434e-02, 8.975e+01
# It: 59060, Loss: 2.271e-02, 1.432e-02, 8.394e+01
# It: 59070, Loss: 2.406e-02, 1.431e-02, 9.742e+01
# It: 59080, Loss: 2.246e-02, 1.428e-02, 8.177e+01
# It: 59090, Loss: 2.313e-02, 1.430e-02, 8.832e+01
# It: 59100, Loss: 2.365e-02, 1.426e-02, 9.391e+01
# It: 59110, Loss: 2.257e-02, 1.430e-02, 8.268e+01
# It: 59120, Loss: 2.396e-02, 1.431e-02, 9.647e+01
# It: 59130, Loss: 2.364e-02, 1.427e-02, 9.365e+01
# It: 59140, Loss: 2.377e-02, 1.434e-02, 9.433e+01
# It: 59150, Loss: 2.301e-02, 1.428e-02, 8.727e+01
# It: 59160, Loss: 2.402e-02, 1.437e-02, 9.652e+01
# It: 59170, Loss: 2.351e-02, 1.434e-02, 9.168e+01
# It: 59180, Loss: 2.371e-02, 1.437e-02, 9.347e+01
# It: 59190, Loss: 2.230e-02, 1.429e-02, 8.013e+01
# It: 59200, Loss: 2.374e-02, 1.431e-02, 9.425e+01
# It: 59210, Loss: 2.304e-02, 1.433e-02, 8.711e+01
# It: 59220, Loss: 2.442e-02, 1.431e-02, 1.012e+02
# It: 59230, Loss: 2.411e-02, 1.459e-02, 9.517e+01
# It: 59240, Loss: 2.529e-02, 1.434e-02, 1.095e+02
# It: 59250, Loss: 2.470e-02, 1.427e-02, 1.043e+02
# It: 59260, Loss: 2.378e-02, 1.437e-02, 9.415e+01
# It: 59270, Loss: 2.262e-02, 1.436e-02, 8.263e+01
# It: 59280, Loss: 2.379e-02, 1.431e-02, 9.481e+01
# It: 59290, Loss: 2.260e-02, 1.431e-02, 8.295e+01
# It: 59300, Loss: 2.287e-02, 1.433e-02, 8.540e+01
# It: 59310, Loss: 2.310e-02, 1.428e-02, 8.822e+01
# It: 59320, Loss: 2.213e-02, 1.431e-02, 7.825e+01
# It: 59330, Loss: 2.272e-02, 1.428e-02, 8.434e+01
# It: 59340, Loss: 2.277e-02, 1.433e-02, 8.445e+01
# It: 59350, Loss: 2.291e-02, 1.432e-02, 8.593e+01
# It: 59360, Loss: 2.296e-02, 1.427e-02, 8.694e+01
# It: 59370, Loss: 2.548e-02, 1.436e-02, 1.112e+02
# It: 59380, Loss: 2.413e-02, 1.429e-02, 9.833e+01
# It: 59390, Loss: 2.232e-02, 1.431e-02, 8.015e+01
# It: 59400, Loss: 2.310e-02, 1.442e-02, 8.680e+01
# It: 59410, Loss: 2.387e-02, 1.441e-02, 9.459e+01
# It: 59420, Loss: 2.308e-02, 1.429e-02, 8.786e+01
# It: 59430, Loss: 2.323e-02, 1.429e-02, 8.939e+01
# It: 59440, Loss: 2.275e-02, 1.424e-02, 8.510e+01
# It: 59450, Loss: 2.201e-02, 1.426e-02, 7.757e+01
# It: 59460, Loss: 2.470e-02, 1.449e-02, 1.021e+02
# It: 59470, Loss: 2.284e-02, 1.428e-02, 8.554e+01
# It: 59480, Loss: 2.487e-02, 1.426e-02, 1.061e+02
# It: 59490, Loss: 2.412e-02, 1.438e-02, 9.737e+01
# It: 59500, Loss: 2.574e-02, 1.456e-02, 1.118e+02
# It: 59510, Loss: 2.386e-02, 1.433e-02, 9.531e+01
# It: 59520, Loss: 2.238e-02, 1.429e-02, 8.086e+01
# It: 59530, Loss: 2.403e-02, 1.430e-02, 9.735e+01
# It: 59540, Loss: 2.570e-02, 1.426e-02, 1.144e+02
# It: 59550, Loss: 2.301e-02, 1.431e-02, 8.702e+01
# It: 59560, Loss: 2.251e-02, 1.434e-02, 8.176e+01
# It: 59570, Loss: 2.265e-02, 1.430e-02, 8.349e+01
# It: 59580, Loss: 2.296e-02, 1.431e-02, 8.645e+01
# It: 59590, Loss: 2.335e-02, 1.425e-02, 9.100e+01
# It: 59600, Loss: 2.465e-02, 1.445e-02, 1.019e+02
# It: 59610, Loss: 2.267e-02, 1.425e-02, 8.421e+01
# It: 59620, Loss: 2.305e-02, 1.428e-02, 8.763e+01
# It: 59630, Loss: 2.582e-02, 1.429e-02, 1.153e+02
# It: 59640, Loss: 2.405e-02, 1.452e-02, 9.526e+01
# It: 59650, Loss: 2.431e-02, 1.435e-02, 9.951e+01
# It: 59660, Loss: 2.304e-02, 1.428e-02, 8.755e+01
# It: 59670, Loss: 2.249e-02, 1.423e-02, 8.258e+01
# It: 59680, Loss: 2.502e-02, 1.427e-02, 1.075e+02
# It: 59690, Loss: 2.327e-02, 1.430e-02, 8.969e+01
# It: 59700, Loss: 2.311e-02, 1.432e-02, 8.793e+01
# It: 59710, Loss: 2.377e-02, 1.426e-02, 9.515e+01
# It: 59720, Loss: 2.310e-02, 1.431e-02, 8.794e+01
# It: 59730, Loss: 2.279e-02, 1.431e-02, 8.478e+01
# It: 59740, Loss: 2.296e-02, 1.434e-02, 8.621e+01
# It: 59750, Loss: 2.353e-02, 1.429e-02, 9.236e+01
# It: 59760, Loss: 2.366e-02, 1.426e-02, 9.401e+01
# It: 59770, Loss: 2.377e-02, 1.424e-02, 9.533e+01
# It: 59780, Loss: 2.321e-02, 1.425e-02, 8.961e+01
# It: 59790, Loss: 2.301e-02, 1.439e-02, 8.620e+01
# It: 59800, Loss: 2.485e-02, 1.432e-02, 1.053e+02
# It: 59810, Loss: 2.471e-02, 1.428e-02, 1.043e+02
# It: 59820, Loss: 2.310e-02, 1.428e-02, 8.813e+01
# It: 59830, Loss: 2.361e-02, 1.427e-02, 9.341e+01
# It: 59840, Loss: 2.228e-02, 1.424e-02, 8.034e+01
# It: 59850, Loss: 2.572e-02, 1.437e-02, 1.136e+02
# It: 59860, Loss: 2.523e-02, 1.422e-02, 1.100e+02
# It: 59870, Loss: 2.277e-02, 1.430e-02, 8.469e+01
# It: 59880, Loss: 2.488e-02, 1.476e-02, 1.012e+02
# It: 59890, Loss: 2.418e-02, 1.432e-02, 9.853e+01
# It: 59900, Loss: 2.427e-02, 1.444e-02, 9.831e+01
# It: 59910, Loss: 2.272e-02, 1.425e-02, 8.468e+01
# It: 59920, Loss: 2.581e-02, 1.427e-02, 1.154e+02
# It: 59930, Loss: 2.374e-02, 1.441e-02, 9.330e+01
# It: 59940, Loss: 2.391e-02, 1.432e-02, 9.588e+01
# It: 59950, Loss: 2.316e-02, 1.428e-02, 8.872e+01
# It: 59960, Loss: 2.255e-02, 1.433e-02, 8.219e+01
# It: 59970, Loss: 2.209e-02, 1.419e-02, 7.895e+01
# It: 59980, Loss: 2.422e-02, 1.425e-02, 9.966e+01
# It: 59990, Loss: 2.278e-02, 1.421e-02, 8.571e+01
# 1 th iterations, Loss: 0.02235519140958786
# 2 th iterations, Loss: 100.8104019165039
# 3 th iterations, Loss: 0.1305365115404129
# 4 th iterations, Loss: 0.02187109924852848
# 5 th iterations, Loss: 0.021778887137770653
# 6 th iterations, Loss: 0.021742960438132286
# 7 th iterations, Loss: 0.02173137292265892
# 8 th iterations, Loss: 0.021718904376029968
# 9 th iterations, Loss: 0.021712718531489372
# 10 th iterations, Loss: 0.021702364087104797
# 11 th iterations, Loss: 0.02169645205140114
# 12 th iterations, Loss: 0.021708078682422638
# 13 th iterations, Loss: 0.02170412987470627
# 14 th iterations, Loss: 0.021695008501410484
# 15 th iterations, Loss: 0.021694909781217575
# 16 th iterations, Loss: 0.02169990725815296
# 17 th iterations, Loss: 0.02169322595000267
# 18 th iterations, Loss: 0.021693231537938118
# 19 th iterations, Loss: 0.02169322595000267
# 20 th iterations, Loss: 0.021705172955989838
# 21 th iterations, Loss: 0.02169489488005638
# 22 th iterations, Loss: 0.021693764254450798
# 23 th iterations, Loss: 0.02169324830174446
# 24 th iterations, Loss: 0.02169322595000267
# 25 th iterations, Loss: 0.02169322595000267
# 26 th iterations, Loss: 0.02169322595000267
# 27 th iterations, Loss: 0.02169322595000267
# 28 th iterations, Loss: 0.02169322595000267
# 29 th iterations, Loss: 0.02169322595000267
# 30 th iterations, Loss: 0.02169322595000267
# 31 th iterations, Loss: 0.02169322595000267
# 32 th iterations, Loss: 0.02169322595000267
# 33 th iterations, Loss: 0.02169322595000267
# 34 th iterations, Loss: 0.02169322595000267
# 35 th iterations, Loss: 0.02169322595000267
# 36 th iterations, Loss: 0.02169322595000267
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.021693
#   Number of iterations: 10
#   Number of functions evaluations: 36
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.021693
#   Number of iterations: 10
#   Number of functions evaluations: 36
# Save NN parameters successfully...
